# %% [markdown]
# ## Assignements
# Les données utilisées dans ce fichier sont extraites du Flux-Rappels-Naissances-Mois-v3 dans RapidPro.
# Elles sont récupérées par le client Postman.
# Et partir de Postman on importe les données sur jupyter.
#
# Ce travail s'intéresse sur la remise des rapports de naissance des agents.

# %%
######Ce bloc fait partie de l"assignement ###########
####Définition des variables utilisées### 
#id   
#'uuid'
#'flow
#'contact'
#'start'
#responded  
#Values
#confirmation_finale               
#depassement_delai_rapportage  
#mois_de_rappel
#'created_on'
#modified_on                       
#exit_type 
#'exit_type'

# %% [markdown]
# ## Extraction des données

# %%
import http.client
import mimetypes
import json
conn = http.client.HTTPSConnection("api.rapidpro.io")
payload = ''
headers = {
  'Authorization': 'Token 50cbd586af288261b69996ef9aaf0a43fb6351a9'
}
conn.request("GET", "/api/v2/runs.json?flow=e665a1b5-2b15-4de6-9d77-4521ff502fc9", payload, headers)
res = conn.getresponse()
data = res.read()

# %% [markdown]
# Les données sont stockées dans la variable 'data'.
#
# Voici la structure des données dans le fichier json.

# %%
import requests
print(data.decode("utf-8"))
# Out:
# {"next":null,"previous":null,"results":[{"id":1046183665,"uuid":"e5188f13-90b2-4d59-a078-3a386c4c7ca8","flow":{"uuid":"e665a1b5-2b15-4de6-9d77-4521ff502fc9","name":"Flux-Rappels-Naissances-Mois-v3"},"contact":{"uuid":"125f43a1-3802-483c-98a7-a1ac8b17c5c5","urn":"tel:+221778075147","name":"Ahmet Khouma"},"start":null,"responded":true,"path":[{"node":"dc534c8e-7f44-4ae0-9cf1-2d602fa390f5","time":"2020-03-12T12:07:42.433071Z"},{"node":"c4b12b47-dd9f-43af-9d33-d6d29ee957ef","time":"2020-03-12T12:07:42.433439Z"},{"node":"214d7574-b4a6-4404-ac9b-11b9fb9ce500","time":"2020-03-12T12:07:42.433551Z"},{"node":"4c004f3c-b346-4edd-b561-67be61e61f4c","time":"2020-03-12T12:08:12.048371Z"},{"node":"d539c831-c52b-4cdc-ad6a-ecec29b3d212","time":"2020-03-12T12:08:12.048686Z"},{"node":"7c14ad67-230e-41a4-87cb-6495cb62b99a","time":"2020-03-12T12:08:12.048962Z"},{"node":"593e9803-0e3a-4ead-9f10-d381596cd46e","time":"2020-03-12T12:08:12.049095Z"},{"node":"680ff8d7-f629-4f9c-8896-93daa05b0140","time":"2020-03-12T12:08:49.464657Z"},{"node":"5d0bd4cd-f7fa-4ed9-bb06-c073f758510e","time":"2020-03-12T12:08:49.465138Z"},{"node":"a4478fed-6c73-4387-821e-e528c888d3ec","time":"2020-03-12T12:08:49.465639Z"},{"node":"6eda4f3b-3303-4d7b-8226-1ac1057f2bae","time":"2020-03-12T12:08:49.465828Z"},{"node":"863a3653-f571-453d-9334-bd44d386b10d","time":"2020-03-12T12:09:15.704656Z"},{"node":"0cd49cee-13a7-4053-b9cd-c86fec33df24","time":"2020-03-12T12:09:15.704955Z"},{"node":"5e4ad7e2-5413-4bef-8fbd-81645e059298","time":"2020-03-12T12:09:15.705205Z"},{"node":"f8dbcb8a-053c-43c0-a426-3563f75ba0a7","time":"2020-03-12T12:09:15.705320Z"},{"node":"b13566d5-109e-437c-b3f2-3d65c5d69db8","time":"2020-03-12T12:09:42.904672Z"},{"node":"2cc1c121-0af1-4e67-a84b-7205e048c773","time":"2020-03-12T12:09:42.905161Z"},{"node":"98883221-bc88-4290-8e5a-ac7305ecce5b","time":"2020-03-12T12:09:42.905622Z"},{"node":"68e1808c-3052-4831-a58e-3d8e2c41d6ae","time":"2020-03-12T12:09:42.907040Z"},{"node":"a38976f1-a939-4450-9172-943293bb3d65","time":"2020-03-12T12:10:06.551752Z"},{"node":"5523a546-a2da-4a6a-be46-dab3fb3d036d","time":"2020-03-12T12:10:06.551820Z"}],"values":{"confirmation_finale":{"value":"Oui","category":"confirmation","node":"68e1808c-3052-4831-a58e-3d8e2c41d6ae","time":"2020-03-12T12:10:06.551724Z","input":"Oui","name":"Confirmation finale"},"filles_nees_dans_annee_en_cours_enregistrees_mois_precedent":{"value":"10","category":"nombre","node":"863a3653-f571-453d-9334-bd44d386b10d","time":"2020-03-12T12:09:15.704937Z","input":"10","name":"filles nees dans annee en cours enregistrees mois precedent"},"filles_regularisees_dans_le_mois_precedent":{"value":"25","category":"nombre","node":"b13566d5-109e-437c-b3f2-3d65c5d69db8","time":"2020-03-12T12:09:42.905139Z","input":"25","name":"filles regularisees dans le mois precedent"},"garcons_nes_dans_annee_en_cours_enregistres_mois_precedent":{"value":"4","category":"nombre","node":"0cd49cee-13a7-4053-b9cd-c86fec33df24","time":"2020-03-12T12:09:15.705190Z","input":"4","name":"garcons nes dans annee en cours enregistres mois precedent"},"garcons_regularises_dans_le_mois_precedent":{"value":"14","category":"nombre","node":"2cc1c121-0af1-4e67-a84b-7205e048c773","time":"2020-03-12T12:09:42.905600Z","input":"14","name":"garcons regularises dans le mois precedent"},"mois_de_rappel":{"value":"Janvier","category":"Janvier","node":"dc534c8e-7f44-4ae0-9cf1-2d602fa390f5","time":"2020-03-12T12:07:42.433424Z","input":"Janvier","name":"Mois de rappel"},"total_de_filles_avec_volet_1_mois_precedents":{"value":"35","category":"nombre","node":"680ff8d7-f629-4f9c-8896-93daa05b0140","time":"2020-03-12T12:08:49.465113Z","input":"35","name":"Total de filles avec volet 1 mois precedents"},"total_de_garcons_avec_volets_1_mois_precedents":{"value":"19","category":"nombre","node":"5d0bd4cd-f7fa-4ed9-bb06-c073f758510e","time":"2020-03-12T12:08:49.465612Z","input":"19","name":"Total de garcons avec volets 1 mois precedents"},"total_enfants_enregistres_mois_precedent":{ ...

# %% [markdown]
# ## Exploitation des données

# %%
type(data)
# Out:
# bytes

# %% [markdown]
# ### Conversion en dictionnaire
# Notre nouvelle variable est data_rappels_naissances.

# %%
data_rappels_naissances = json.loads(data)
type(data_rappels_naissances)
# Out:
# dict

# %% [markdown]
# ### Extraction des informations de la clé 'results' de notre dictionnaire 'data_rappels_naissances'
# Le travail restant ne portant que sur la valeur de la clé 'result', on affecte le resultat à notre variable 'data_rappels_naissances'.

# %%
data_rappels_naissances = data_rappels_naissances.get("results")
type(data_rappels_naissances)
# Out:
# list

# %% [markdown]
# #### Un exemple de la structure de notre liste 'data_rappels_naissances' :

# %%
data_rappels_naissances[0]
# Out:
# {'id': 1046183665,
#  'uuid': 'e5188f13-90b2-4d59-a078-3a386c4c7ca8',
#  'flow': {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9',
#   'name': 'Flux-Rappels-Naissances-Mois-v3'},
#  'contact': {'uuid': '125f43a1-3802-483c-98a7-a1ac8b17c5c5',
#   'urn': 'tel:+221778075147',
#   'name': 'Ahmet Khouma'},
#  'start': None,
#  'responded': True,
#  'path': [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f5',
#    'time': '2020-03-12T12:07:42.433071Z'},
#   {'node': 'c4b12b47-dd9f-43af-9d33-d6d29ee957ef',
#    'time': '2020-03-12T12:07:42.433439Z'},
#   {'node': '214d7574-b4a6-4404-ac9b-11b9fb9ce500',
#    'time': '2020-03-12T12:07:42.433551Z'},
#   {'node': '4c004f3c-b346-4edd-b561-67be61e61f4c',
#    'time': '2020-03-12T12:08:12.048371Z'},
#   {'node': 'd539c831-c52b-4cdc-ad6a-ecec29b3d212',
#    'time': '2020-03-12T12:08:12.048686Z'},
#   {'node': '7c14ad67-230e-41a4-87cb-6495cb62b99a',
#    'time': '2020-03-12T12:08:12.048962Z'},
#   {'node': '593e9803-0e3a-4ead-9f10-d381596cd46e',
#    'time': '2020-03-12T12:08:12.049095Z'},
#   {'node': '680ff8d7-f629-4f9c-8896-93daa05b0140',
#    'time': '2020-03-12T12:08:49.464657Z'},
#   {'node': '5d0bd4cd-f7fa-4ed9-bb06-c073f758510e',
#    'time': '2020-03-12T12:08:49.465138Z'},
#   {'node': 'a4478fed-6c73-4387-821e-e528c888d3ec',
#    'time': '2020-03-12T12:08:49.465639Z'},
#   {'node': '6eda4f3b-3303-4d7b-8226-1ac1057f2bae',
#    'time': '2020-03-12T12:08:49.465828Z'},
#   {'node': '863a3653-f571-453d-9334-bd44d386b10d',
#    'time': '2020-03-12T12:09:15.704656Z'},
#   {'node': '0cd49cee-13a7-4053-b9cd-c86fec33df24',
#    'time': '2020-03-12T12:09:15.704955Z'},
#   {'node': '5e4ad7e2-5413-4bef-8fbd-81645e059298',
#    'time': '2020-03-12T12:09:15.705205Z'},
#   {'node': 'f8dbcb8a-053c-43c0-a426-3563f75ba0a7',
#    'time': '2020-03-12T12:09:15.705320Z'},
#   {'node': 'b13566d5-109e-437c-b3f2-3d65c5d69db8',
#    'time': '2020-03-12T12:09:42.904672Z'},
#   {'node': '2cc1c121-0af1-4e67-a84b-7205e048c773',
#    'time': '2020-03-12T12:09:42.905161Z'},
#   {'node': '98883221-bc88-4290-8e5a-ac7305ecce5b',
#    'time': '2020-03-12T12:09:42.905622Z'},
#   {'node': '68e1808c-3052-4831-a58e-3d8e2c41d6ae',
#    'time': '2020-03-12T12:09:42.907040Z'},
#   {'node': 'a38976f1-a939-4450-9172-943293bb3d65',
#    'time': '2020-03-12T12:10:06.551752Z'},
#   {'node': '5523a546-a2da-4a6a-be46-dab3fb3d036d',
#    'time': '2020-03-12T12:10:06.551820Z'}],
#  'values': {'confirmation_finale': {'value': 'Oui',
#    'category': 'confirmation',
#    'node': '68e1808c-3052-4831-a58e-3d8e2c41d6ae',
#    'time': '2020-03-12T12:10:06.551724Z',
#    'input': 'Oui',
#    'name': 'Confirmation finale'},
#   'filles_nees_dans_annee_en_cours_enregistrees_mois_precedent': {'value': '10',
#    'category': 'nombre',
#    'node': '863a3653-f571-453d-9334-bd44d386b10d',
#    'time': '2020-03-12T12:09:15.704937Z',
#    'input': '10',
#    'name': 'filles nees dans annee en cours enregistrees mois precedent'},
#   'filles_regularisees_dans_le_mois_precedent': {'value': '25',
#    'category': 'nombre',
#    'node': 'b13566d5-109e-437c-b3f2-3d65c5d69db8',
#    'time': '2020-03-12T12:09:42.905139Z',
#    'input': '25',
#    'name': 'filles regularisees dans le mois precedent'},
#   'garcons_nes_dans_annee_en_cours_enregistres_mois_precedent': {'value': '4',
#    'category': 'nombre',
#    'node': '0cd49cee-13a7-4053-b9cd-c86fec33df24',
#    'time': '2020-03-12T12:09:15.705190Z',
#    'input': '4',
#    'name': 'garcons nes dans annee en cours enregistres mois precedent'},
#   'garcons_regularises_dans_le_mois_precedent': {'value': '14',
#    'category': 'nombre',
#    'node': '2cc1c121-0af1-4e67-a84b-7205e048c773',
#    'time': '2020-03-12T12:09:42.905600Z',
#    'input': '14',
#    'name': 'garcons regularises dans le mois precedent'},
#   'mois_de_rappel': {'value': 'Janvier',
#    'category': 'Janvier',
#    'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f5',
#    'time': '2020-03-12T12:07:42.433424Z',
#    'input': 'Janvier',
#    'name': 'Mois de rappel'},
#   'total_de_filles_avec_volet_1_mois_precedents': {'value': '35',
#    'category': 'nombre',
#    'node': '680ff8d7-f629-4f9c-8896-93daa05b0140',
#    'time': '2020-03-12T12:08:49.465113Z',
#    'input': '35',
#    'name': 'Total de filles avec volet 1 mois precedents'},
#   'total_de_garcons_avec_volets_1_mois_precedents': {'value': '19',
#    'category': 'nombre',
#    'node': '5d0bd4cd-f7fa-4ed9-bb06-c073f758510e',
#    'time': '2020-03-12T12:08:49.465612Z',
#    'input': '19',
#    'name': 'Total de garcons avec volets 1 mois precedents'},
#   'total_enfants_enregistres_mois_precedent': {'value': 'F 35 g 19',
#    'category': 'valide',
#    'node': '214d7574-b4a6-4404-ac9b-11b9fb9ce500',
#    'time': '2020-03-12T12:08:12.048324Z',
#    'input': 'F 35 g 19',
#    'name': 'Total enfants enregistres mois precedent'},
#   'total_enfants_nes_dans_annee_en_cours_enregistres_mois_precedent': {'value': 'F 10 g 4',
#    'category': 'valide',
#    'node': '6eda4f3b-3303-4d7b-8226-1ac1057f2bae',
#    'time': '2020-03-12T12:09:15.704616Z',
#    'input': 'F 10 g 4',
#    'name': 'Total enfants nes dans annee en cours enregistres mois precedent'},
#   'total_enfants_regularises_dans_le_mois_precedent': {'value': 'F 25 g 14',
#    'category': 'valide',
#    'node': 'f8dbcb8a-053c-43c0-a426-3563f75ba0a7',
#    'time': '2020-03-12T12:09:42.904615Z',
#    'input': 'F 25 g 14',
#    'name': 'Total enfants regularises dans le mois precedent'},
#   'total_filles_enregistres_mois_precedent': {'value': '35',
#    'category': 'Nombre',
#    'node': '4c004f3c-b346-4edd-b561-67be61e61f4c',
#    'time': '2020-03-12T12:08:12.048671Z',
#    'input': '35',
#    'name': 'Total Filles Enregistres Mois Precedent'},
#   'total_garcons_enregistres_mois_precedents': {'value': '19',
#    'category': 'Nombre',
#    'node': 'd539c831-c52b-4cdc-ad6a-ecec29b3d212',
#    'time': '2020-03-12T12:08:12.048947Z',
#    'input': '19',
#    'name': 'Total Garcons Enregistres Mois Precedents'},
#   'total_volets_1_delivres_mois_precedents': {'value': 'F 35 g 19',
#    'category': 'valide',
#    'node': '593e9803-0e3a-4ead-9f10-d381596cd46e',
#    'time': '2020-03-12T12:08:49.464590Z',
#    'input': 'F 35 g 19',
#    'name': 'total volets 1 delivres mois precedents'}},
#  'created_on': '2020-03-12T12:07:42.433051Z',
#  'modified_on': '2020-03-12T12:10:06.565197Z',
#  'exited_on': '2020-03-12T12:10:06.561831Z',
#  'exit_type': 'completed'}

# %% [markdown]
# ## Transformation des données

# %% [markdown]
# ###  Extension de chaque dictionnaire de la liste data_rappels_naissances par les colonnes suivantes :
# -Extraction des valeurs de la clé 'contact' :
#  'contact_uuid',  'contact_name', 'contact_urn'
#
# -Extraction des valeurs de la clé 'values' :
#  'confirmation_finale', 'depassement_delai_rapportage', 'mois_de_rappel'

# %%
#Extension de chaque dictionnaire de la liste dataB par les champs :
#   contact_name, contact_uuid, contact_urn
for a in  range(0,len(data_rappels_naissances) - 1):
    
    #Extraction des valeurs du champs 'contact'
    contact_uuid = data_rappels_naissances[a].get('contact').get('uuid')
    contact_urn = data_rappels_naissances[a].get('contact').get('urn')
    contact_name = data_rappels_naissances[a].get('contact').get('name')
    
    #Extraction des valeurs du champ 'values'
    if 'confirmation_finale' in data_rappels_naissances[a].get('values'):
        confirmation_finale = data_rappels_naissances[a].get('values').get('confirmation_finale').get('value')
    if 'depassement_delai_rapportage' in data_rappels_naissances[a].get('values'):
        depassement_delai_rapportage = data_rappels_naissances[a].get('values').get('depassement_delai_rapportage').get('value')
        data_rappels_naissances[a]['depassement_delai_rapportage'] = depassement_delai_rapportage
    if 'mois_de_rappel' in data_rappels_naissances[a].get('values'):
        mois_de_rappel = data_rappels_naissances[a].get('values').get('mois_de_rappel').get('value')
    
    data_rappels_naissances[a].update({'contact_uuid' :contact_uuid,
                                       'contact_urn' : contact_urn,
                                       'contact_name' : contact_name,
                                       'confirmation_finale': confirmation_finale,
                                       'mois_de_rappel' : mois_de_rappel})

# %% [markdown]
# ### Conversion de la liste 'data_rappels_naissances' en dataFrame
#
# Importation de la librairie pandas

# %%
#importer la librairie pandas et convertir la liste en dataframe
import pandas as pd
data_rappels_naissances = pd.DataFrame(data_rappels_naissances)
data_rappels_naissances
# Out:
#             id                                  uuid  \
# 0   1046183665  e5188f13-90b2-4d59-a078-3a386c4c7ca8
# 1   1045785646  b30f7e8b-c03e-4712-a50d-6099c1d70153
# 2   1045678295  1e69b35d-c20f-4163-af1b-f7285d715af9
# 3   1045618112  5a37eb5c-3a93-4a5b-9c62-ec358d9ef8b6
# 4   1037196734  97fdd271-4b01-461a-9757-cdbe5d1dc601
# 5   1036223982  4c266f5e-369d-4499-86c2-0100ba84b883
# 6   1036223915  8287c236-ba1f-4780-b3d4-18b18c90ac62
# 7   1027560162  b4288d1c-b631-4524-84db-f5c77560ad39
# 8   1027060539  df9c7f64-1a0c-4f96-ba8a-e14db409cec0
# 9   1027060491  21fed133-8b94-4a56-8bba-d547e666837a
# 10  1027060419  25be2e70-a6fa-49b8-94ee-ca9ee48c0816
# 11  1027060342  5f95e455-8703-4fec-b58c-45cdb9a7eaaf
# 12  1027060276  2848183e-0200-48bc-afbb-0adc4e11e148
# 13  1024292818  094e4cc5-db79-43ba-a43c-36f8e73d1043
# 14  1024149695  e40fecb1-9a39-4b95-9522-429a712aca92
#
#                                                  flow  \
# 0   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 1   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 2   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 3   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 4   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 5   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 6   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 7   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 8   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 9   {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 10  {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 11  {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 12  {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 13  {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
# 14  {'uuid': 'e665a1b5-2b15-4de6-9d77-4521ff502fc9...
#
#                                               contact start  responded  \
# 0   {'uuid': '125f43a1-3802-483c-98a7-a1ac8b17c5c5...  None       True
# 1   {'uuid': '94b1e99d-81f4-49a5-9cb5-026f34783c28...  None       True
# 2   {'uuid': '4e4229dd-a938-4546-b783-fa77b816e9e5...  None       True
# 3   {'uuid': '4e4229dd-a938-4546-b783-fa77b816e9e5...  None       True
# 4   {'uuid': '1f308250-1cfb-4afc-8eed-2ee052f28cb1...  None       True
# 5   {'uuid': '555ab6e4-c7a4-4fb6-8a9d-96dcaaa1fb60...  None       True
# 6   {'uuid': '555ab6e4-c7a4-4fb6-8a9d-96dcaaa1fb60...  None       True
# 7   {'uuid': '94b1e99d-81f4-49a5-9cb5-026f34783c28...  None       True
# 8   {'uuid': '997591a5-601b-414b-9947-f5fbd57cac1b...  None       True
# 9   {'uuid': '997591a5-601b-414b-9947-f5fbd57cac1b...  None       True
# 10  {'uuid': '997591a5-601b-414b-9947-f5fbd57cac1b...  None       True
# 11  {'uuid': '997591a5-601b-414b-9947-f5fbd57cac1b...  None       True
# 12  {'uuid': '997591a5-601b-414b-9947-f5fbd57cac1b...  None       True
# 13  {'uuid': '753aa53c-6498-44dd-a034-30a8e76615f3...  None       True
# 14  {'uuid': '753aa53c-6498-44dd-a034-30a8e76615f3...  None       True
#
#                                                  path  \
# 0   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 1   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 2   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 3   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 4   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 5   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 6   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 7   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 8   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 9   [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 10  [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 11  [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 12  [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 13  [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
# 14  [{'node': 'dc534c8e-7f44-4ae0-9cf1-2d602fa390f...
#
#                                                values  \
# 0   {'confirmation_finale': {'value': 'Oui', 'cate...
# 1   {'confirmation_finale': {'value': 'Oui', 'cate...
# 2   {'confirmation_finale': {'value': 'Oui', 'cate...
# 3   {'confirmation_finale': {'value': 'Oui', 'cate...
# 4   {'confirmation_finale': {'value': 'O', 'catego...
# 5   {'confirmation_finale': {'value': 'O', 'catego...
# 6   {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 7   {'depassement_delai_rapportage': {'value': '2'...
# 8   {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 9   {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 10  {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 11  {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 12  {'mois_de_rappel': {'value': 'Janvier', 'categ...
# 13  {'depassement_delai_rapportage': {'value': '1'...
# 14  {'mois_de_rappel': {'value': 'Janvier', 'categ...
#
#                      created_on                  modified_on  \
# 0   2020-03-12T12:07:42.433051Z  2020-03-12T12:10:06.565197Z
# 1   2020-03-11T10:11:28.856786Z  2020-03-11T10:17:11.240672Z
# 2   2020-03-10T17:13:49.597684Z  2020-03-10T17:17:34.435436Z
# 3   2020-03-10T09:27:05.272308Z  2020-03-10T17:12:10.380565Z
# 4   2020-02-27T13:00:52.913570Z  2020-02-27T13:09:43.023637Z
# 5   2020-02-25T13:48:49.516778Z  2020-02-25T13:55:01.845763Z
# 6   2020-02-25T13:47:05.073954Z  2020-02-25T13:48:28.817589Z
# 7   2020-02-13T15:12:54.696752Z  2020-02-20T15:17:01.791374Z
# 8   2020-02-12T16:00:22.766596Z  2020-02-12T16:03:55.455269Z
# 9   2020-02-12T15:58:35.536505Z  2020-02-12T16:00:06.166563Z
# 10  2020-02-12T15:56:01.871719Z  2020-02-12T15:58:14.427754Z
# 11  2020-02-12T15:53:33.353466Z  2020-02-12T15:55:42.536123Z
# 12  2020-02-12T15:50:38.782710Z  2020-02-12T15:53:11.483429Z
# 13  2020-02-06T12:24:33.823517Z  2020-02-07T12:33:28.788752Z
# 14  2020-02-05T14:08:22.779913Z  2020-02-06T12:23:31.082017Z
#
#                       exited_on    exit_type  \
# 0   2020-03-12T12:10:06.561831Z    completed
# 1   2020-03-11T10:17:11.239094Z    completed
# 2   2020-03-10T17:17:34.435292Z    completed
# 3   2020-03-10T17:12:10.379228Z    completed
# 4   2020-02-27T13:09:43.021225Z    completed
# 5   2020-02-25T13:55:01.844339Z    completed
# 6   2020-02-25T13:48:28.813488Z  interrupted
# 7   2020-02-20T15:17:01.791245Z    completed
# 8   2020-02-12T16:03:55.372020Z  interrupted
# 9   2020-02-12T16:00:06.161591Z  interrupted
# 10  2020-02-12T15:58:14.423514Z  interrupted
# 11  2020-02-12T15:55:42.532523Z  interrupted
# 12  2020-02-12T15:53:11.479273Z  interrupted
# 13  2020-02-07T12:33:28.788313Z    completed
# 14  2020-02-06T12:23:31.078073Z  interrupted
#
#                             contact_uuid        contact_urn  \
# 0   125f43a1-3802-483c-98a7-a1ac8b17c5c5  tel:+221778075147
# 1   94b1e99d-81f4-49a5-9cb5-026f34783c28  tel:+221770463545
# 2   4e4229dd-a938-4546-b783-fa77b816e9e5  tel:+221773576816
# 3   4e4229dd-a938-4546-b783-fa77b816e9e5  tel:+221773576816
# 4   1f308250-1cfb-4afc-8eed-2ee052f28cb1  tel:+221772315672
# 5   555ab6e4-c7a4-4fb6-8a9d-96dcaaa1fb60  tel:+221775142350
# 6   555ab6e4-c7a4-4fb6-8a9d-96dcaaa1fb60  tel:+221775142350
# 7   94b1e99d-81f4-49a5-9cb5-026f34783c28  tel:+221770463545
# 8   997591a5-601b-414b-9947-f5fbd57cac1b  tel:+221773547183
# 9   997591a5-601b-414b-9947-f5fbd57cac1b  tel:+221773547183
# 10  997591a5-601b-414b-9947-f5fbd57cac1b  tel:+221773547183
# 11  997591a5-601b-414b-9947-f5fbd57cac1b  tel:+221773547183
# 12  997591a5-601b-414b-9947-f5fbd57cac1b  tel:+221773547183
# 13  753aa53c-6498-44dd-a034-30a8e76615f3  tel:+221782806785
# 14                                   NaN                NaN
#
#             contact_name confirmation_finale mois_de_rappel  \
# 0           Ahmet Khouma                 Oui        Janvier
# 1   Mamadou Malado Sylla                 Oui        Janvier
# 2       Fatou Kine Gueye                 Oui        Fevrier
# 3       Fatou Kine Gueye                 Oui        Janvier
# 4    Alphousseyny Mballo                   O        Janvier
# 5           Dicory Baldé                   O        Janvier
# 6           Dicory Baldé                   O        Janvier
# 7   Mamadou Malado Sylla                   O        Janvier
# 8          Aminata Balde                   O        Janvier
# 9          Aminata Balde                   O        Janvier
# 10         Aminata Balde                   O        Janvier
# 11         Aminata Balde                   O        Janvier
# 12         Aminata Balde                   O        Janvier
# 13          Lamine Balde                   O        Janvier
# 14                   NaN                 NaN            NaN
#
#    depassement_delai_rapportage
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                             2
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                            1
# 14                          NaN

# %% [markdown]
# ### Division de la colonne 'created_on' en deux colonnes différentes :
# - 'create_on_date'
# - 'create_on_heure'

# %%
data_rappels_naissances=data_rappels_naissances.join(data_rappels_naissances['created_on'].str.split('T', 1, expand=True).rename(columns={0:'created_on_date', 1:'created_on_heure'}))

# %% [markdown]
# #### Conversion de la colonne 'created_on_date' au format datatime

# %%
data_rappels_naissances.created_on_date= pd.to_datetime(data_rappels_naissances.created_on_date)

# %% [markdown]
# #### Creation des colonnes: 'created_on_year', 'created_on_month', 'created_on_day'

# %%
data_rappels_naissances['created_on_year'] = data_rappels_naissances['created_on_date'].dt.year
data_rappels_naissances['created_on_month'] = data_rappels_naissances['created_on_date'].dt.month
data_rappels_naissances['created_on_day'] = data_rappels_naissances['created_on_date'].dt.day

# %% [markdown]
# ### Suppression des colonnes qu'on ne vas pas utiliser

# %%
data_rappels_naissances = data_rappels_naissances.drop(['uuid', 'flow', 'start', 'path', 'contact','created_on', 'values', 'exited_on', 'created_on_date',], axis=1)

# %% [markdown]
# ### Affichage des colonnes restantes et de la taille du DataFrame     'data_rappels_naissancess'

# %%
print(data_rappels_naissances.columns)
print(data_rappels_naissances.shape)
# Out:
# Index(['id', 'responded', 'modified_on', 'exit_type', 'contact_uuid',
#        'contact_urn', 'contact_name', 'confirmation_finale', 'mois_de_rappel',
#        'depassement_delai_rapportage', 'created_on_heure', 'created_on_year',
#        'created_on_month', 'created_on_day'],
#       dtype='object')
# (15, 14)

# %% [markdown]
# ### Le type de données de chaque colonne du DataFrame

# %%
data_rappels_naissances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 14 columns):
# id                              15 non-null int64
# responded                       15 non-null bool
# modified_on                     15 non-null object
# exit_type                       15 non-null object
# contact_uuid                    14 non-null object
# contact_urn                     14 non-null object
# contact_name                    14 non-null object
# confirmation_finale             14 non-null object
# mois_de_rappel                  14 non-null object
# depassement_delai_rapportage    2 non-null object
# created_on_heure                15 non-null object
# created_on_year                 15 non-null int64
# created_on_month                15 non-null int64
# created_on_day                  15 non-null int64
# dtypes: bool(1), int64(4), object(9)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Le nombre de valeurs manquantes pour chaque variable du DataFrame 'data_rapport_naissances'

# %%
data_rappels_naissances.isna().sum()
# Out:
# id                               0
# responded                        0
# modified_on                      0
# exit_type                        0
# contact_uuid                     1
# contact_urn                      1
# contact_name                     1
# confirmation_finale              1
# mois_de_rappel                   1
# depassement_delai_rapportage    13
# created_on_heure                 0
# created_on_year                  0
# created_on_month                 0
# created_on_day                   0
# dtype: int64

# %% [markdown]
# #### Conversion de la colonne 'depassement_delai_rapportage' en entier
# Avant de convertir, on remplace les NAN par des zéros.

# %%
data_rappels_naissances['depassement_delai_rapportage'] = data_rappels_naissances['depassement_delai_rapportage'].fillna(0)

data_rappels_naissances['depassement_delai_rapportage'] = data_rappels_naissances['depassement_delai_rapportage'].astype(int)
