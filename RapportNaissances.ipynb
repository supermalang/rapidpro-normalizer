# %% [markdown]
# ## Assignements
# Les données utilisées dans ce fichier sont extraites du **Flux-Rapports-Naissances-Mois-v3** dans RapidPro.
# Elles sont récupérées par le client Postman.
# Et à partir de Postman on importe les données sur jupyter.
#
# Ce travail s'intéresse sur la remise des rapports de naissances des agents.

# %%
######Ce bloc fait partie de l"assignement ###########
####Définition des variables utilisées### 
#id   
#'uuid'
#'flow
#'contact'
#'start'
#responded  
#Values
#confirmation_finale               
#depassement_delai_rapportage    
#'created_on'
#modified_on                       
#exit_type 
#'exit_type'

# %% [markdown]
# ## Extraction des données

# %%
import http.client
import mimetypes
import json
conn = http.client.HTTPSConnection("api.rapidpro.io")
payload = ''
headers = {
  'Authorization': 'Token votre_Token'
}
conn.request("GET", "/api/v2/runs.json?flow=bb56ec73-0246-42e1-bc0b-632a6f2a4d81", payload, headers)
res = conn.getresponse()
data = res.read()

# %% [markdown]
# Les données sont stockées dans la variable 'data'.
#
# Voici la structure des données dans le fichier json.

# %%
import requests
print(data.decode("utf-8"))
# Out:
# {"next":null,"previous":null,"results":[{"id":1080274391,"uuid":"765cf1b8-4f91-4a80-addc-d0cbebfe1101","flow":{"uuid":"bb56ec73-0246-42e1-bc0b-632a6f2a4d81","name":"Flux-Rapports-Naissances-Mois-v3"},"contact":{"uuid":"806b655d-8514-4d23-b63f-16ceed9c5ea5","urn":"tel:+221781863937","name":"Abdoulaye Bald\u00e9"},"start":null,"responded":true,"path":[{"node":"f2233887-b79a-4b6f-adf4-9607ec28026d","time":"2020-04-08T10:22:48.806644Z"},{"node":"3fd5387c-7b19-451c-af5b-48301bc583fb","time":"2020-04-08T10:22:48.807427Z"},{"node":"dcd722e0-1199-4325-810b-5623b98d2209","time":"2020-04-08T10:23:24.013486Z"},{"node":"a40c392d-e25c-42a7-b0a9-edcb3944f0b6","time":"2020-04-08T10:23:24.013900Z"},{"node":"f343d65b-a724-4c19-affb-01bc08fdf2a6","time":"2020-04-08T10:23:24.014247Z"},{"node":"f599d17b-6590-4d36-99a0-0c5c56375c21","time":"2020-04-08T10:23:24.014492Z"},{"node":"6869004e-e639-4d86-a9d4-8a2bb7d99d6b","time":"2020-04-08T10:23:52.901808Z"},{"node":"d9e34504-b97e-4317-b391-5da685bac7a9","time":"2020-04-08T10:23:52.902094Z"},{"node":"2dd260f0-0920-4485-b58e-97ec06a571d8","time":"2020-04-08T10:23:52.902346Z"},{"node":"4a600977-5afc-4509-884a-6900d0f618fa","time":"2020-04-08T10:23:52.902509Z"},{"node":"69e287d3-d96d-46ef-8856-44b8db412938","time":"2020-04-08T10:24:23.867951Z"},{"node":"a97b1c71-4045-47fb-9551-e202cf837a11","time":"2020-04-08T10:24:23.868236Z"},{"node":"5e19229e-b76e-4b25-a110-5c527f4ddec4","time":"2020-04-08T10:24:23.868491Z"},{"node":"7608bca5-1215-4357-a8b1-bdb062b9549e","time":"2020-04-08T10:24:23.868689Z"},{"node":"9c79e8e5-65f0-4a94-b93f-2099e7bb3646","time":"2020-04-08T10:24:51.560903Z"},{"node":"fcbec99c-12bf-4063-a397-f22c45d48d84","time":"2020-04-08T10:24:51.561337Z"},{"node":"986d3392-ecb3-45f2-bbd2-b3c70ce95e62","time":"2020-04-08T10:24:51.561758Z"},{"node":"069ccaf1-3402-4e1c-81c6-4ffc72a37502","time":"2020-04-08T10:24:51.564365Z"},{"node":"2e919ce8-703c-495d-b835-3ed94bf9b09d","time":"2020-04-08T10:25:19.717686Z"},{"node":"815036f7-b6f8-4aa6-a81e-c1a595daeda7","time":"2020-04-08T10:25:19.718047Z"}],"values":{"confirmation_finale":{"value":"O","category":"confirmation","node":"069ccaf1-3402-4e1c-81c6-4ffc72a37502","time":"2020-04-08T10:25:19.717665Z","input":"O","name":"Confirmation finale"},"filles_nees_dans_annee_en_cours_enregistrees_mois_precedent":{"value":"43","category":"nombre","node":"69e287d3-d96d-46ef-8856-44b8db412938","time":"2020-04-08T10:24:23.868220Z","input":"43","name":"filles nees dans annee en cours enregistrees mois precedent"},"filles_regularisees_dans_le_mois_precedent":{"value":"0","category":"nombre","node":"9c79e8e5-65f0-4a94-b93f-2099e7bb3646","time":"2020-04-08T10:24:51.561316Z","input":"0","name":"filles regularisees dans le mois precedent"},"garcons_nes_dans_annee_en_cours_enregistres_mois_precedent":{"value":"37","category":"nombre","node":"a97b1c71-4045-47fb-9551-e202cf837a11","time":"2020-04-08T10:24:23.868474Z","input":"37","name":"garcons nes dans annee en cours enregistres mois precedent"},"garcons_regularises_dans_le_mois_precedent":{"value":"0","category":"nombre","node":"fcbec99c-12bf-4063-a397-f22c45d48d84","time":"2020-04-08T10:24:51.561737Z","input":"0","name":"garcons regularises dans le mois precedent"},"total_de_filles_avec_volet_1_mois_precedents":{"value":"43","category":"nombre","node":"6869004e-e639-4d86-a9d4-8a2bb7d99d6b","time":"2020-04-08T10:23:52.902079Z","input":"43","name":"Total de filles avec volet 1 mois precedents"},"total_de_garcons_avec_volets_1_mois_precedents":{"value":"37","category":"nombre","node":"d9e34504-b97e-4317-b391-5da685bac7a9","time":"2020-04-08T10:23:52.902331Z","input":"37","name":"Total de garcons avec volets 1 mois precedents"},"total_enfants_enregistres_mois_precedent":{"value":"F 43 G 37","category":"valide","node":"3fd5387c-7b19-451c-af5b-48301bc583fb","time":"2020-04-08T10:23:24.013413Z","input":"F 43 G 37","name":"Total enfants enregistres mois precedent"},"total_enfants_nes_dans_annee_en_cours_enregistres_mois_precedent":{"va ...

# %% [markdown]
# ## Exploitation des données

# %%
#Type des données 'data'
type(data)
# Out:
# bytes

# %% [markdown]
# ### Conversion en dictionnaire
#
# Notre nouvelle variable est data_rapport_naissances.

# %%
data_rapport_naissances = json.loads(data)
type(data_rapport_naissances)
# Out:
# dict

# %% [markdown]
# ### Extraction des informations de la clé 'results' de notre dictionnaire 'data_rapport_naissances'
# Le travail restant ne portant que sur la valeur de la clé 'result', on affecte le resultat à notre variable 'data_rapport_naissances'.

# %%
data_rapport_naissances = data_rapport_naissances.get("results")
type(data_rapport_naissances)
# Out:
# list

# %% [markdown]
# #### Un exemple de la structure de notre liste 'data_rapport_naissances'

# %%
data_rapport_naissances[1]
# Out:
# {'id': 1080067280,
#  'uuid': '13c207ff-80fd-4556-ac4d-c6b5fbe78706',
#  'flow': {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81',
#   'name': 'Flux-Rapports-Naissances-Mois-v3'},
#  'contact': {'uuid': 'cda55fbf-5f8d-48e6-83fd-6fc37ddb9233',
#   'urn': 'tel:+221771477199',
#   'name': 'Demba Balde'},
#  'start': None,
#  'responded': True,
#  'path': [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026d',
#    'time': '2020-04-07T13:26:24.642892Z'},
#   {'node': '3fd5387c-7b19-451c-af5b-48301bc583fb',
#    'time': '2020-04-07T13:26:24.643317Z'},
#   {'node': 'dcd722e0-1199-4325-810b-5623b98d2209',
#    'time': '2020-04-07T13:27:50.219326Z'},
#   {'node': 'a40c392d-e25c-42a7-b0a9-edcb3944f0b6',
#    'time': '2020-04-07T13:27:50.219694Z'},
#   {'node': 'f343d65b-a724-4c19-affb-01bc08fdf2a6',
#    'time': '2020-04-07T13:27:50.220031Z'},
#   {'node': 'f599d17b-6590-4d36-99a0-0c5c56375c21',
#    'time': '2020-04-07T13:27:50.220237Z'},
#   {'node': '6869004e-e639-4d86-a9d4-8a2bb7d99d6b',
#    'time': '2020-04-07T13:28:35.811173Z'},
#   {'node': 'd9e34504-b97e-4317-b391-5da685bac7a9',
#    'time': '2020-04-07T13:28:35.811485Z'},
#   {'node': '2dd260f0-0920-4485-b58e-97ec06a571d8',
#    'time': '2020-04-07T13:28:35.811763Z'},
#   {'node': '4a600977-5afc-4509-884a-6900d0f618fa',
#    'time': '2020-04-07T13:28:35.811921Z'},
#   {'node': '69e287d3-d96d-46ef-8856-44b8db412938',
#    'time': '2020-04-07T13:29:20.402457Z'},
#   {'node': 'a97b1c71-4045-47fb-9551-e202cf837a11',
#    'time': '2020-04-07T13:29:20.402774Z'},
#   {'node': '5e19229e-b76e-4b25-a110-5c527f4ddec4',
#    'time': '2020-04-07T13:29:20.403044Z'},
#   {'node': '7608bca5-1215-4357-a8b1-bdb062b9549e',
#    'time': '2020-04-07T13:29:20.403197Z'},
#   {'node': '9c79e8e5-65f0-4a94-b93f-2099e7bb3646',
#    'time': '2020-04-07T13:29:50.614301Z'},
#   {'node': 'fcbec99c-12bf-4063-a397-f22c45d48d84',
#    'time': '2020-04-07T13:29:50.614700Z'},
#   {'node': '986d3392-ecb3-45f2-bbd2-b3c70ce95e62',
#    'time': '2020-04-07T13:29:50.615038Z'},
#   {'node': '069ccaf1-3402-4e1c-81c6-4ffc72a37502',
#    'time': '2020-04-07T13:29:50.616007Z'},
#   {'node': '2e919ce8-703c-495d-b835-3ed94bf9b09d',
#    'time': '2020-04-07T13:30:50.803335Z'},
#   {'node': '815036f7-b6f8-4aa6-a81e-c1a595daeda7',
#    'time': '2020-04-07T13:30:50.803532Z'}],
#  'values': {'confirmation_finale': {'value': 'O',
#    'category': 'confirmation',
#    'node': '069ccaf1-3402-4e1c-81c6-4ffc72a37502',
#    'time': '2020-04-07T13:30:50.803322Z',
#    'input': 'O',
#    'name': 'Confirmation finale'},
#   'filles_nees_dans_annee_en_cours_enregistrees_mois_precedent': {'value': '49',
#    'category': 'nombre',
#    'node': '69e287d3-d96d-46ef-8856-44b8db412938',
#    'time': '2020-04-07T13:29:20.402758Z',
#    'input': '49',
#    'name': 'filles nees dans annee en cours enregistrees mois precedent'},
#   'filles_regularisees_dans_le_mois_precedent': {'value': '54',
#    'category': 'nombre',
#    'node': '9c79e8e5-65f0-4a94-b93f-2099e7bb3646',
#    'time': '2020-04-07T13:29:50.614685Z',
#    'input': '54',
#    'name': 'filles regularisees dans le mois precedent'},
#   'garcons_nes_dans_annee_en_cours_enregistres_mois_precedent': {'value': '34',
#    'category': 'nombre',
#    'node': 'a97b1c71-4045-47fb-9551-e202cf837a11',
#    'time': '2020-04-07T13:29:20.403027Z',
#    'input': '34',
#    'name': 'garcons nes dans annee en cours enregistres mois precedent'},
#   'garcons_regularises_dans_le_mois_precedent': {'value': '60',
#    'category': 'nombre',
#    'node': 'fcbec99c-12bf-4063-a397-f22c45d48d84',
#    'time': '2020-04-07T13:29:50.615022Z',
#    'input': '60',
#    'name': 'garcons regularises dans le mois precedent'},
#   'total_de_filles_avec_volet_1_mois_precedents': {'value': '130',
#    'category': 'nombre',
#    'node': '6869004e-e639-4d86-a9d4-8a2bb7d99d6b',
#    'time': '2020-04-07T13:28:35.811470Z',
#    'input': '130',
#    'name': 'Total de filles avec volet 1 mois precedents'},
#   'total_de_garcons_avec_volets_1_mois_precedents': {'value': '119',
#    'category': 'nombre',
#    'node': 'd9e34504-b97e-4317-b391-5da685bac7a9',
#    'time': '2020-04-07T13:28:35.811747Z',
#    'input': '119',
#    'name': 'Total de garcons avec volets 1 mois precedents'},
#   'total_enfants_enregistres_mois_precedent': {'value': 'F 130 g 119',
#    'category': 'valide',
#    'node': '3fd5387c-7b19-451c-af5b-48301bc583fb',
#    'time': '2020-04-07T13:27:50.219248Z',
#    'input': 'F 130 g 119',
#    'name': 'Total enfants enregistres mois precedent'},
#   'total_enfants_nes_dans_annee_en_cours_enregistres_mois_precedent': {'value': 'F 49 G 34',
#    'category': 'valide',
#    'node': '4a600977-5afc-4509-884a-6900d0f618fa',
#    'time': '2020-04-07T13:29:20.402405Z',
#    'input': 'F 49 G 34',
#    'name': 'Total enfants nes dans annee en cours enregistres mois precedent'},
#   'total_enfants_regularises_dans_le_mois_precedent': {'value': 'F 54 g 60',
#    'category': 'valide',
#    'node': '7608bca5-1215-4357-a8b1-bdb062b9549e',
#    'time': '2020-04-07T13:29:50.614265Z',
#    'input': 'F 54 g 60',
#    'name': 'Total enfants regularises dans le mois precedent'},
#   'total_filles_enregistres_mois_precedent': {'value': '130',
#    'category': 'Nombre',
#    'node': 'dcd722e0-1199-4325-810b-5623b98d2209',
#    'time': '2020-04-07T13:27:50.219678Z',
#    'input': '130',
#    'name': 'Total Filles Enregistres Mois Precedent'},
#   'total_garcons_enregistres_mois_precedents': {'value': '119',
#    'category': 'Nombre',
#    'node': 'a40c392d-e25c-42a7-b0a9-edcb3944f0b6',
#    'time': '2020-04-07T13:27:50.220016Z',
#    'input': '119',
#    'name': 'Total Garcons Enregistres Mois Precedents'},
#   'total_volets_1_delivres_mois_precedents': {'value': 'F 130 g 119',
#    'category': 'valide',
#    'node': 'f599d17b-6590-4d36-99a0-0c5c56375c21',
#    'time': '2020-04-07T13:28:35.811137Z',
#    'input': 'F 130 g 119',
#    'name': 'total volets 1 delivres mois precedents'}},
#  'created_on': '2020-04-07T13:26:24.642879Z',
#  'modified_on': '2020-04-07T13:30:50.840975Z',
#  'exited_on': '2020-04-07T13:30:50.840109Z',
#  'exit_type': 'completed'}

# %% [markdown]
# ## Transformation des données

# %% [markdown]
# ###  Extension de chaque dictionnaire de la liste data_rapport_naissances par les colonnes suivantes :
# -Extraction des valeurs de la clé 'contact' :
#  'contact_uuid',  'contact_name', 'contact_urn'
#
# -Extraction des valeurs de la clé 'values' :
#  'confirmation_finale', 'depassement_delai_rapportage'

# %%
for a in  range(0,len(data_rapport_naissances) - 1):
    
    #Extraction des valeurs de la clé 'contact'
    contact_uuid = data_rapport_naissances[a].get('contact').get('uuid')
    contact_urn = data_rapport_naissances[a].get('contact').get('urn')
    contact_name =data_rapport_naissances[a].get('contact').get('name')
    
    #Extraction des valeurs de la clé 'values'
    if 'confirmation_finale' in data_rapport_naissances[a].get('values'):
        confirmation_finale = data_rapport_naissances[a].get('values').get('confirmation_finale').get('value')    
    if 'depassement_delai_rapportage' in data_rapport_naissances[a].get('values'):
        depassement_delai_rapportage = data_rapport_naissances[a].get('values').get('depassement_delai_rapportage').get('value')
        data_rapport_naissances[a]['depassement_delai_rapportage'] = depassement_delai_rapportage        
 
    data_rapport_naissances[a].update({'contact_uuid' : contact_uuid,
                                       'contact_urn' : contact_urn,
                                       'contact_name' : contact_name,
                                       'confirmation_finale': confirmation_finale})

# %% [markdown]
# ### Conversion de la liste 'data_rapport_naissances' en dataFrame

# %%
import pandas as pd
data_rapport_naissances = pd.DataFrame(data_rapport_naissances)
data_rapport_naissances
# Out:
#              id                                  uuid  \
# 0    1080274391  765cf1b8-4f91-4a80-addc-d0cbebfe1101
# 1    1080067280  13c207ff-80fd-4556-ac4d-c6b5fbe78706
# 2    1076021437  dfa9a67c-ca88-47bf-85a2-17805eec28da
# 3    1076408510  58f593eb-7fbb-49b1-ab64-be62b9911cc0
# 4    1076072438  aa941ddb-3c87-41e8-bc1c-f52707e1d50c
# ..          ...                                   ...
# 97   1009042230  5fac23d5-cc38-47d8-ac27-a7c31340e543
# 98   1007804002  e95831d0-1104-4038-9d5b-68b6b61acc90
# 99   1007784428  70d87a0a-b471-463e-9101-9740bcefe943
# 100  1007783837  b7411a23-b898-4461-8e3d-da703b9cb742
# 101  1005821602  326973cb-286c-4edf-8892-f00afcc9d865
#
#                                                   flow  \
# 0    {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 1    {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 2    {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 3    {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 4    {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# ..                                                 ...
# 97   {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 98   {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 99   {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 100  {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
# 101  {'uuid': 'bb56ec73-0246-42e1-bc0b-632a6f2a4d81...
#
#                                                contact start  responded  \
# 0    {'uuid': '806b655d-8514-4d23-b63f-16ceed9c5ea5...  None       True
# 1    {'uuid': 'cda55fbf-5f8d-48e6-83fd-6fc37ddb9233...  None       True
# 2    {'uuid': 'f42c8310-f5a6-4211-9169-bd3ba4aa4cd7...  None       True
# 3    {'uuid': 'e17389f3-acb9-43bc-b7e6-349cb4739ab8...  None       True
# 4    {'uuid': 'e17389f3-acb9-43bc-b7e6-349cb4739ab8...  None       True
# ..                                                 ...   ...        ...
# 97   {'uuid': 'bbdd8018-2e97-4065-9a6d-20edafde00d6...  None       True
# 98   {'uuid': '8f2bdbcd-8840-45f2-bcbf-5fc0efacbd96...  None       True
# 99   {'uuid': '806b655d-8514-4d23-b63f-16ceed9c5ea5...  None       True
# 100  {'uuid': 'c59cdd6e-45b7-4f3d-bf5c-8b14031bf84e...  None       True
# 101  {'uuid': '9c4b6664-61a9-42b0-8e69-c74fc923670d...  None       True
#
#                                                   path  \
# 0    [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 1    [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 2    [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 3    [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 4    [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# ..                                                 ...
# 97   [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 98   [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 99   [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 100  [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
# 101  [{'node': 'f2233887-b79a-4b6f-adf4-9607ec28026...
#
#                                                 values  \
# 0    {'confirmation_finale': {'value': 'O', 'catego...
# 1    {'confirmation_finale': {'value': 'O', 'catego...
# 2    {'depassement_delai_rapportage': {'value': '3'...
# 3    {'confirmation_finale': {'value': 'Oui', 'cate...
# 4    {'confirmation_finale': {'value': 'F 17 g 16',...
# ..                                                 ...
# 97   {'confirmation_finale': {'value': 'O', 'catego...
# 98   {'confirmation_finale': {'value': 'O', 'catego...
# 99   {'confirmation_finale': {'value': 'O', 'catego...
# 100  {'confirmation_finale': {'value': 'oui', 'cate...
# 101  {'depassement_delai_rapportage': {'value': '1'...
#
#                       created_on                  modified_on  \
# 0    2020-04-08T10:22:48.806618Z  2020-04-08T10:25:19.749111Z
# 1    2020-04-07T13:26:24.642879Z  2020-04-07T13:30:50.840975Z
# 2    2020-04-06T09:25:38.400269Z  2020-04-07T09:28:01.481695Z
# 3    2020-04-06T13:17:15.731830Z  2020-04-06T13:20:56.631027Z
# 4    2020-04-06T11:40:59.632906Z  2020-04-06T13:17:15.733266Z
# ..                           ...                          ...
# 97   2020-01-15T21:05:47.709057Z  2020-01-15T21:09:47.170778Z
# 98   2020-01-15T09:36:16.915702Z  2020-01-15T09:41:07.745492Z
# 99   2020-01-14T16:00:54.959030Z  2020-01-14T16:04:40.671072Z
# 100  2020-01-14T14:48:40.289006Z  2020-01-14T14:55:51.698745Z
# 101  2020-01-09T09:17:17.967507Z  2020-01-10T09:20:15.423712Z
#
#                        exited_on    exit_type  \
# 0    2020-04-08T10:25:19.747027Z    completed
# 1    2020-04-07T13:30:50.840109Z    completed
# 2                           None         None
# 3    2020-04-06T13:20:56.629563Z    completed
# 4    2020-04-06T13:17:15.714232Z  interrupted
# ..                           ...          ...
# 97   2020-01-15T21:09:47.169501Z    completed
# 98   2020-01-15T09:41:07.743724Z    completed
# 99   2020-01-14T16:04:40.669734Z    completed
# 100  2020-01-14T14:55:51.697506Z    completed
# 101  2020-01-10T09:20:15.144407Z    completed
#
#                              contact_uuid        contact_urn     contact_name  \
# 0    806b655d-8514-4d23-b63f-16ceed9c5ea5  tel:+221781863937  Abdoulaye Baldé
# 1    cda55fbf-5f8d-48e6-83fd-6fc37ddb9233  tel:+221771477199      Demba Balde
# 2    f42c8310-f5a6-4211-9169-bd3ba4aa4cd7  tel:+221785868105  Sounkarou Balde
# 3    e17389f3-acb9-43bc-b7e6-349cb4739ab8  tel:+221772172734      Saliou Diao
# 4    e17389f3-acb9-43bc-b7e6-349cb4739ab8  tel:+221772172734      Saliou Diao
# ..                                    ...                ...              ...
# 97   bbdd8018-2e97-4065-9a6d-20edafde00d6  tel:+221779934207  Fatoumata Balde
# 98   8f2bdbcd-8840-45f2-bcbf-5fc0efacbd96  tel:+221781428298       Mariama Ba
# 99   806b655d-8514-4d23-b63f-16ceed9c5ea5  tel:+221781863937  Abdoulaye Baldé
# 100  c59cdd6e-45b7-4f3d-bf5c-8b14031bf84e  tel:+221779185387      Aliou Balde
# 101                                   NaN                NaN              NaN
#
#     confirmation_finale depassement_delai_rapportage
# 0                     O                          NaN
# 1                     O                          NaN
# 2                     O                            3
# 3                   Oui                          NaN
# 4             F 17 g 16                            1
# ..                  ...                          ...
# 97                    O                          NaN
# 98                    O                          NaN
# 99                    O                          NaN
# 100                 oui                          NaN
# 101                 NaN                          NaN
#
# [102 rows x 17 columns]

# %% [markdown]
# ### Conversion de la colonne 'created_on' au format datatime

# %%
data_rapport_naissances.created_on= pd.to_datetime(data_rapport_naissances.created_on)

# %% [markdown]
# ### Suppression des colonnes qu'on ne vas pas utiliser

# %%
data_rapport_naissances = data_rapport_naissances.drop(['uuid','flow', 'contact', 'start', 
                                    'path', 'values', 'exited_on',], axis=1)

# %% [markdown]
# ### Affichage des colonnes restantes et de la taille du DataFrame     'data_rapport_naissances'

# %%
print(data_rapport_naissances.columns)
print(data_rapport_naissances.shape)
# Out:
# Index(['id', 'responded', 'created_on', 'modified_on', 'exit_type',
#        'contact_uuid', 'contact_urn', 'contact_name', 'confirmation_finale',
#        'depassement_delai_rapportage'],
#       dtype='object')
# (102, 10)

# %% [markdown]
# ### Le type de données de chaque colonne du DataFrame

# %%
data_rapport_naissances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 10 columns):
# id                              102 non-null int64
# responded                       102 non-null bool
# created_on                      102 non-null datetime64[ns, UTC]
# modified_on                     102 non-null object
# exit_type                       101 non-null object
# contact_uuid                    101 non-null object
# contact_urn                     93 non-null object
# contact_name                    99 non-null object
# confirmation_finale             101 non-null object
# depassement_delai_rapportage    13 non-null object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(1), object(7)
# memory usage: 7.4+ KB

# %% [markdown]
# ### Le nombre de valeurs manquantes pour chaque variable du DataFrame 'data_rapport_naissances'

# %%
data_rapport_naissances.isna().sum()
# Out:
# id                               0
# responded                        0
# created_on                       0
# modified_on                      0
# exit_type                        1
# contact_uuid                     1
# contact_urn                      9
# contact_name                     3
# confirmation_finale              1
# depassement_delai_rapportage    89
# dtype: int64

# %% [markdown]
# #### Conversion de la colonne 'depassement_delai_rapportage' en entier
# Avant de convertir, on remplace les NAN par des zéros.

# %%
data_rapport_naissances['depassement_delai_rapportage']=data_rapport_naissances['depassement_delai_rapportage'].fillna(0)

data_rapport_naissances['depassement_delai_rapportage']= data_rapport_naissances['depassement_delai_rapportage'].astype(int)

# %%
len(data_rapport_naissances)
# Out:
# 102
