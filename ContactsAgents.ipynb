# %% [markdown]
# ## Assignements
# Les données utilisées dans ce fichier sont extraites de l'API **GET /api/v2/contacts.json** dans RapidPro.
# Elles sont récupérées par le client Postman.
# Et à partir de Postman on importe les données sur jupyter.
#
# Ce travail s'intéresse sur la remise des rapports de naissances des agents.

# %%
######Ce bloc fait partie de l'assignement ###########
####Définition des variables utilisées### 
#'uuid',
#'language',
#'groups': {'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa064',
    
 #'fields': {
  #'date_rapport_agent',
  # 'compteur_retard_rapport_agent_ec',,
  #'date_rapport_de_rappel',
  #'rappels_de_rapport',
  #'reporting_month',
  #'date_rapport',
  #'mois_dernier_rapport': None,
  #'ec': 'oui',
  #'annee_en_cours': None,
  # date_completude_du_rapport': None,
  #'mois_de_rappel'},
    
#'blocked',
#'stopped',
#'created_on',
#'modified_on'

# %% [markdown]
# ## Extraction des données

# %%
import http.client
import mimetypes
import json
conn = http.client.HTTPSConnection("api.rapidpro.io")
payload = ''
headers = {
  'Authorization': 'Token 50cbd586af288261b69996ef9aaf0a43fb6351a9'
}
conn.request("GET", "/api/v2/contacts.json?flow=bb56ec73-0246-42e1-bc0b-632a6f2a4d81", payload, headers)
res = conn.getresponse()
data = res.read()

# %% [markdown]
# Les données sont stockées dans la variable 'data'.
#
# Voici la structure des données dans le fichier json.

# %%
import requests

# %%
print(data.decode("utf-8"))
# Out:
# {"next":"https://api.rapidpro.io/api/v2/contacts.json?cursor=cD0yMDE4LTA4LTEwKzE3JTNBMDYlM0EyOC41MTk3NzUlMkIwMCUzQTAw&flow=bb56ec73-0246-42e1-bc0b-632a6f2a4d81","previous":null,"results":[{"uuid":"0a0d115e-c5b9-4d9c-9bd0-3f0ca81bcf26","name":"Thierno Balde","language":null,"urns":["tel:+221772274715"],"groups":[{"uuid":"f2417638-175b-4c57-b63e-36c6b7afa064","name":"REGION: Kolda"},{"uuid":"1cc1cb0d-1831-4439-8c4a-246d091a1da0","name":"DEPARTEMENT: Kolda"},{"uuid":"7c998ea2-eec4-4a94-a2a0-0100918f95ad","name":"COMMUNE: KO_Sare Yoba Diega"},{"uuid":"8fd6898d-2846-42f9-bd35-75b7dda3d0d0","name":"Etat Civil Kolda Contacts 2019 01 21"},{"uuid":"0f364be1-5610-4d0c-8f7e-edaa6163b6c8","name":"Copy Of Contacts Pf Rapidpro Etat Civil Kolda Inputs"},{"uuid":"418db794-96cc-49f2-b0e9-deb7ba3769d6","name":"Etat Civil Kolda Contacts 2019 01 21 2"},{"uuid":"ee3a7f5a-e5a4-4c95-bf30-acf9380b99ad","name":"Kolda Ec Agents Contactlist Rapidpro"}],"fields":{"vote_vdj":null,"auxiliaire":null,"centre_de_sante":null,"poste_de_sante":null,"agent_etat_civil":null,"prefecture":null,"last_seen":null,"besoins":null,"region":null,"nb_enseignants":null,"nb_enseignants_presents":null,"eleves_inscrits":null,"nb_eleves_absent":null,"nb_presents":null,"district":null,"activit":null,"milieu":null,"scoretest1":null,"informatisation":null,"nombre_de_pc":null,"officiers_etat_civil":null,"nombre_de_registre_de_naissance":null,"nombre_de_registre_de_mariage":null,"nombre_de_registre_de_deces":null,"nombre_extraits_de_naissance":null,"nombre_copie_litterale_de_naissance":null,"nombre_de_certificats_de_mariage":null,"nombre_copies_litterales_mariage":null,"nombre_de_certificats_de_deces":null,"nombre_de_copies_litterales_deces":null,"type_centre":null,"district_sanitaire":null,"date_rp_naissances_attendues":null,"case_de_sante":null,"sexe":null,"date_de_naissance":null,"prenoms_de_la_mere":null,"icp":null,"sage_femme":null,"chef_de_centre_etat_civil":null,"infirmier":null,"relais":null,"mcd":null,"ssp":null,"telephone":null,"state":null,"school":null,"safety_status":null,"prenoms_nom":null,"secretaire_municipal":null,"date_enregistrement":null,"joined_date":null,"date_rapport_agent":null,"compteur_retard_rapport_agent_ec":"2","email":null,"date_rapport_de_rappel":"03-10-2018","rappels_de_rapport":"0","donnees_rapport_ec_aout":"Total enregistr\u00e9s F: 2  G: 4  Total volet 1 F: 2 G: 4 Total n\u00e9s dans ann\u00e9e en cours  F: 2 G: 4 Total r\u00e9gularisations  F: 0 G: 0","reporting_month":"Juillet","date_rapport":"2020-04-20T11:29:30.467883Z","departement":"Kolda","counter":null,"statut":null,"fonction":"agent","donnees_rapport_ec_avril":"Total enregistr\u00e9s F: 5  G: 5  Total volet 1 F: 5 G: 5 Total n\u00e9s dans ann\u00e9e en cours  F: 5 G: 3 Total r\u00e9gularisations  F: 0 G: 0","mois_de_rapport":"Mars","donnees_rapport_ec_fevrier":"Total enregistr\u00e9s F: 4  G: 8  Total volet 1 F: 4 G: 8 Total n\u00e9s dans ann\u00e9e en cours  F: 4 G: 8 Total r\u00e9gularisations  F: 0 G: 1","donnees_rapport_ec_janvier":"Total enregistr\u00e9s F: 3  G: 4  Total volet 1 F: 3 G: 4 Total n\u00e9s dans ann\u00e9e en cours  F: 3 G: 4 Total r\u00e9gularisations  F: 0 G: 0","donnees_rapport_ec_juin":"Total enregistr\u00e9s F: 11  G: 13  Total volet 1 F: 11 G: 13 Total n\u00e9s dans ann\u00e9e en cours  F: 11 G: 13 Total r\u00e9gularisations  F: 0 G: 0","donnees_rapport_ec_mai":"Total enregistr\u00e9s F: 4  G: 8  Total volet 1 F: 4 G: 8 Total n\u00e9s dans ann\u00e9e en cours  F: 4 G: 8 Total r\u00e9gularisations  F: 0 G: 0","mois_dernier_rapport":"Mars","nom_du_centre":null,"commune":"Sare Yoba Diega","ec":"oui","donnees_rapport_ec_septembre":"Total enregistr\u00e9s F: 6  G: 8  Total volet 1 F: 6 G: 8 Total n\u00e9s dans ann\u00e9e en cours  F: 4 G: 8 Total r\u00e9gularisations  F: 2 G: 0","annee_en_cours":"2020","donnees_rapport_ec_decembre":"Total enregistr\u00e9s F: 10  G: 18  Total volet 1 F: 10 G: 19 Total n\u00e9s dans ann\u00e9e en cours  F: 0 G: 0 Total r\u00e9gularisations ...

# %% [markdown]
# ## Exploitation des données

# %%
type(data)
# Out:
# bytes

# %% [markdown]
# ### Conversion en dictionnaire

# %%
data_contacts_agents = json.loads(data)
type(data_contacts_agents)
# Out:
# dict

# %% [markdown]
# ### Extraction des informations de la clé 'results' de notre dictionnaire 'data_contacts_agents'

# %%
data_contacts_agents = data_contacts_agents.get("results")
type(data_contacts_agents)
# Out:
# list

# %% [markdown]
# #### Un exemple de la structure de notre liste 'data_contacts_agents'

# %%
data_contacts_agents[120]
# Out:
# {'uuid': 'b70c8809-b87c-4047-b85d-c7434f59a09f',
#  'name': 'Bacary Saboly',
#  'language': None,
#  'urns': ['tel:+221773235619'],
#  'groups': [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa064',
#    'name': 'REGION: Kolda'},
#   {'uuid': '8701bbbc-c201-4490-a19f-69e28e42335f', 'name': 'DEPARTEMENT: MYF'},
#   {'uuid': '839568ec-7332-4168-a5c1-fa724bbb4a38',
#    'name': 'COMMUNE: MYF_Koulinto'},
#   {'uuid': '0f364be1-5610-4d0c-8f7e-edaa6163b6c8',
#    'name': 'Copy Of Contacts Pf Rapidpro Etat Civil Kolda Inputs'},
#   {'uuid': 'ee3a7f5a-e5a4-4c95-bf30-acf9380b99ad',
#    'name': 'Kolda Ec Agents Contactlist Rapidpro'}],
#  'fields': {'vote_vdj': None,
#   'auxiliaire': None,
#   'centre_de_sante': None,
#   'poste_de_sante': None,
#   'agent_etat_civil': None,
#   'prefecture': None,
#   'last_seen': None,
#   'besoins': None,
#   'region': None,
#   'nb_enseignants': None,
#   'nb_enseignants_presents': None,
#   'eleves_inscrits': None,
#   'nb_eleves_absent': None,
#   'nb_presents': None,
#   'district': None,
#   'activit': None,
#   'milieu': None,
#   'scoretest1': None,
#   'informatisation': None,
#   'nombre_de_pc': None,
#   'officiers_etat_civil': None,
#   'nombre_de_registre_de_naissance': None,
#   'nombre_de_registre_de_mariage': None,
#   'nombre_de_registre_de_deces': None,
#   'nombre_extraits_de_naissance': None,
#   'nombre_copie_litterale_de_naissance': None,
#   'nombre_de_certificats_de_mariage': None,
#   'nombre_copies_litterales_mariage': None,
#   'nombre_de_certificats_de_deces': None,
#   'nombre_de_copies_litterales_deces': None,
#   'type_centre': None,
#   'district_sanitaire': None,
#   'date_rp_naissances_attendues': None,
#   'case_de_sante': None,
#   'sexe': None,
#   'date_de_naissance': None,
#   'prenoms_de_la_mere': None,
#   'icp': None,
#   'sage_femme': None,
#   'chef_de_centre_etat_civil': None,
#   'infirmier': None,
#   'relais': None,
#   'mcd': None,
#   'ssp': None,
#   'telephone': None,
#   'state': None,
#   'school': None,
#   'safety_status': None,
#   'prenoms_nom': None,
#   'secretaire_municipal': None,
#   'date_enregistrement': None,
#   'joined_date': None,
#   'date_rapport_agent': None,
#   'compteur_retard_rapport_agent_ec': '1',
#   'email': None,
#   'date_rapport_de_rappel': '04-09-2018',
#   'rappels_de_rapport': '0',
#   'donnees_rapport_ec_aout': 'Total enregistrés F:3  G:6  Total volet 1 F: 3 G: 6 Total nés dans année en cours  F: 2 G: 5 Total régularisations  F: 0 G: 0',
#   'reporting_month': 'Juillet',
#   'date_rapport': '2019-06-03T15:40:16.100411Z',
#   'departement': 'MYF',
#   'counter': None,
#   'statut': None,
#   'fonction': 'agent',
#   'donnees_rapport_ec_avril': 'Total enregistrés F: 2  G: 7  Total volet 1 F: 2 G: 7 Total nés dans année en cours  F: 2 G: 6 Total régularisations  F: 0 G: 0',
#   'mois_de_rapport': 'Mai',
#   'donnees_rapport_ec_fevrier': 'Total enregistrés F: 11  G: 10  Total volet 1 F: 11 G: 10 Total nés dans année en cours  F: 0 G: 1 Total régularisations  F: 0 G: 1',
#   'donnees_rapport_ec_janvier': 'Total enregistrés F:21  G:24  Total volet 1 F: 22 G: 23 Total nés dans année en cours  F: 5 G: 2 Total régularisations  F: 0 G: 0',
#   'donnees_rapport_ec_juin': 'Total enregistrés F:6  G:15  Total volet 1 F: 6 G: 15 Total nés dans année en cours  F: 4 G: 14 Total régularisations  F: 0 G: 0',
#   'donnees_rapport_ec_mai': 'Total enregistrés F:16  G:19  Total volet 1 F: 16 G: 18 Total nés dans année en cours  F: 14 G: 17 Total régularisations  F: 0 G: 0',
#   'mois_dernier_rapport': 'Mai',
#   'nom_du_centre': None,
#   'commune': 'Koulinto',
#   'ec': 'oui',
#   'donnees_rapport_ec_septembre': None,
#   'annee_en_cours': '2019',
#   'donnees_rapport_ec_decembre': 'Total enregistrés F: 9  G: 5  Total volet 1 F: 9 G: 5 Total nés dans année en cours  F: 9 G: 5 Total régularisations  F: 0 G: 0',
#   'donnees_rapport_ec_juillet': None,
#   'donnees_rapport_ec_novembre': 'Total enregistrés F: 15  G: 18  Total volet 1 F: 15 G: 18 Total nés dans année en cours  F: 15 G: 18 Total régularisations  F: 0 G: 0',
#   'donnees_rapport_ec_mars': 'Total enregistrés F:13  G:10  Total volet 1 F: 12 G: 10 Total nés dans année en cours  F: 6 G: 6 Total régularisations  F: 0 G: 0',
#   'date_completude_du_rapport': None,
#   'mois_de_rappel': None,
#   'donnees_rapport_ec_octobre': 'Total enregistrés F: 13  G: 12  Total volet 1 F: 13 G: 12 Total nés dans année en cours  F: 9 G: 11 Total régularisations  F: 0 G: 0'},
#  'blocked': False,
#  'stopped': False,
#  'created_on': '2018-08-07T14:36:18.190125Z',
#  'modified_on': '2020-03-16T12:36:13.665919Z'}

# %% [markdown]
# ## Transformation des données

# %% [markdown]
# ### Extension de chaque dictionnaire de la liste data_contacts_agents par les colonnes suivantes :
# -Extraction des valeurs de la clé 'groups' : 'name'(pour extraire la Région)
#
# -Extraction des valeurs de la clé 'fields' : 'departement', 'commune', 'date_enregistrement', 'date_rapport_agent', 'compteur_retard_rapport_agent_ec', 'date_rapport_de_rappel', 'reporting_month', 'date_rapport', 'mois_de_rapport', 'mois_dernier_rapport', 'ec', 'annee_en_cours',
# 'date_completude_du_rapport', 'mois_de_rappel'

# %%
for a in  range(len(data_contacts_agents)):
    #Extraction des valeurs du champs 'groups'
    if not data_contacts_agents[a]['groups']:
        continue
    else :
        Region = data_contacts_agents[a]['groups'][0]['name']
        #Departement = data_contacts_agents[a]['groups'][1]['name']
        #Commune = data_contacts_agents[a]['groups'][2]['name']
        
    Departement = data_contacts_agents[a]['fields'].get('departement')
    Commune = data_contacts_agents[a]['fields'].get('commune')   
    compteur_retard_rapport_agent_ec= data_contacts_agents[a]['fields'].get('compteur_retard_rapport_agent_ec')
    date_rapport_de_rappel = data_contacts_agents[a]['fields'].get('date_rapport_de_rappel')
    rappels_de_rapport = data_contacts_agents[a]['fields'].get('rappels_de_rapport')
    reporting_month = data_contacts_agents[a]['fields'].get('reporting_month')
    date_rapport = data_contacts_agents[a]['fields'].get('date_rapport')
    mois_de_rapport = data_contacts_agents[a]['fields'].get('mois_de_rapport')
    mois_dernier_rapport = data_contacts_agents[a]['fields'].get('mois_dernier_rapport')
    ec = data_contacts_agents[a]['fields'].get('ec')
    annee_en_cours = data_contacts_agents[a]['fields'].get('annee_en_cours')
    date_completude_du_rapport = data_contacts_agents[a]['fields'].get('date_completude_du_rapport')
    mois_de_rappel = data_contacts_agents[a]['fields'].get('mois_de_rappel')
    data_contacts_agents[a].update({'Region': Region,
                                    'Departement' : Departement,
                                    'Commune': Commune,
                                    'compteur_retard_rapport_agent_ec' : compteur_retard_rapport_agent_ec,
                                    'date_rapport_de_rappel' : date_rapport_de_rappel,
                                    'rappels_de_rapport' : rappels_de_rapport,
                                    'reporting_month' : reporting_month,
                                    'date_rapport' : date_rapport,
                                    'mois_de_rapport' : mois_de_rapport,
                                    'mois_dernier_rapport' : mois_dernier_rapport,
                                    'ec' : ec,
                                    'annee_en_cours' : annee_en_cours,
                                    'date_completude_du_rapport' : date_completude_du_rapport,
                                    'mois_de_rappel' : mois_de_rappel})

# %% [markdown]
# ### Conversion de la liste 'data_contacts_agents' en dataFrame

# %%
import pandas as pd
import numpy as np
data_contacts_agents = pd.DataFrame(data_contacts_agents)
data_contacts_agents
# Out:
#                                      uuid                  name language  \
# 0    0a0d115e-c5b9-4d9c-9bd0-3f0ca81bcf26         Thierno Balde     None
# 1    57e9ae0a-bae8-440e-934e-0c37cc66c762    Boubacar Niang Myf
# 2    652f1371-b322-43b0-8fa5-699727191ed4         Amadou Diallo     None
# 3    08b5c66a-eede-483a-ae53-72f9067165f2            Maoudo Sow     None
# 4    94b1e99d-81f4-49a5-9cb5-026f34783c28  Mamadou Malado Sylla
# ..                                    ...                   ...      ...
# 245  0fec6136-4226-48d1-a06b-fe00f2f2e386                  None     None
# 246  e934a365-bc04-422c-bfe1-56b26dd19f94                  None     None
# 247  70549ef2-820d-4bfc-8c4c-f5844ac37a3b                  None     None
# 248  79e3e91f-4367-402c-aece-866cf8478d48                  None     None
# 249  e145e0b8-98a5-4d39-a6e1-1b5e352d78f8                  None     None
#
#                     urns                                             groups  \
# 0    [tel:+221772274715]  [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa06...
# 1                     []  [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa06...
# 2    [tel:+221772301137]  [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa06...
# 3    [tel:+221771607528]  [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa06...
# 4    [tel:+221770463545]  [{'uuid': 'f2417638-175b-4c57-b63e-36c6b7afa06...
# ..                   ...                                                ...
# 245  [tel:+221770349177]  [{'uuid': 'd3e63352-fd30-48c8-a17b-44272ee6bd3...
# 246  [tel:+221771458033]                                                 []
# 247  [tel:+221770600027]                                                 []
# 248  [tel:+221775146637]                                                 []
# 249  [tel:+221771092902]                                                 []
#
#                                                 fields  blocked  stopped  \
# 0    {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 1    {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 2    {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 3    {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 4    {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# ..                                                 ...      ...      ...
# 245  {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 246  {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 247  {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 248  {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
# 249  {'vote_vdj': None, 'auxiliaire': None, 'centre...    False    False
#
#                       created_on                  modified_on  ...  \
# 0    2018-08-08T15:58:21.231678Z  2020-04-20T11:32:02.513763Z  ...
# 1    2017-08-25T11:17:42.633780Z  2020-04-16T18:13:01.842715Z  ...
# 2    2017-08-27T22:38:51.900502Z  2020-04-16T17:34:01.834487Z  ...
# 3    2018-08-09T14:21:19.192594Z  2020-04-16T13:47:48.094575Z  ...
# 4    2018-08-10T10:12:31.962892Z  2020-04-16T11:08:12.202380Z  ...
# ..                           ...                          ...  ...
# 245  2017-06-23T17:16:07.292874Z  2018-08-13T09:10:13.826241Z  ...
# 246  2018-08-11T16:25:09.496947Z  2018-08-11T16:34:39.452544Z  ...
# 247  2018-08-11T12:16:01.390128Z  2018-08-11T12:21:20.363966Z  ...
# 248  2017-08-25T11:22:30.701085Z  2018-08-10T21:47:59.946532Z  ...
# 249  2018-08-09T14:21:30.561167Z  2018-08-10T17:06:28.519775Z  ...
#
#     date_rapport_de_rappel rappels_de_rapport reporting_month  \
# 0               03-10-2018                  0         Juillet
# 1               03-10-2018                  6         Juillet
# 2               10-01-2019                  6         Juillet
# 3               15-08-2018                  6         Juillet
# 4               10-01-2019                  5         Juillet
# ..                     ...                ...             ...
# 245                   None               None         Juillet
# 246                    NaN                NaN             NaN
# 247                    NaN                NaN             NaN
# 248                    NaN                NaN             NaN
# 249                    NaN                NaN             NaN
#
#                     date_rapport mois_de_rapport mois_dernier_rapport    ec  \
# 0    2020-04-20T11:29:30.467883Z            Mars                 Mars   oui
# 1    2020-03-10T18:09:07.451954Z         Fevrier              Fevrier  None
# 2    2020-03-10T17:27:06.081372Z         Fevrier              Fevrier   oui
# 3    2020-03-05T17:23:18.071725Z         Fevrier                 Mars   oui
# 4    2020-04-16T11:03:54.106707Z            Mars                 Mars   oui
# ..                           ...             ...                  ...   ...
# 245                         None            None                 None  None
# 246                          NaN             NaN                  NaN   NaN
# 247                          NaN             NaN                  NaN   NaN
# 248                          NaN             NaN                  NaN   NaN
# 249                          NaN             NaN                  NaN   NaN
#
#     annee_en_cours date_completude_du_rapport mois_de_rappel
# 0             2020                 20-04-2020           None
# 1             2020                 10-03-2020           None
# 2             2020                       None        Juillet
# 3             2020                       None           Mars
# 4             2020                 16-04-2020        Janvier
# ..             ...                        ...            ...
# 245           None                       None           None
# 246            NaN                        NaN            NaN
# 247            NaN                        NaN            NaN
# 248            NaN                        NaN            NaN
# 249            NaN                        NaN            NaN
#
# [250 rows x 24 columns]

# %% [markdown]
# ### Suppression des colonnes qu'on ne vas pas utiliser

# %%
# les colonnes qu'il faut supprimer
data_contacts_agents=data_contacts_agents.drop(['uuid','language', 'groups', 'fields',], axis=1)

# %% [markdown]
# ### Affichage des colonnes restantes et de la taille du DataFrame 'data_contacts_agents'

# %%
print(data_contacts_agents.columns)
# Out:
# Index(['name', 'urns', 'blocked', 'stopped', 'created_on', 'modified_on',
#        'Region', 'Departement', 'Commune', 'compteur_retard_rapport_agent_ec',
#        'date_rapport_de_rappel', 'rappels_de_rapport', 'reporting_month',
#        'date_rapport', 'mois_de_rapport', 'mois_dernier_rapport', 'ec',
#        'annee_en_cours', 'date_completude_du_rapport', 'mois_de_rappel'],
#       dtype='object')

# %% [markdown]
# ### Le nombre de valeurs manquantes pour chaque variable du DataFrame 'data_contacts_agents'

# %%
data_contacts_agents.isna().sum()
# Out:
# name                                 87
# urns                                  0
# blocked                               0
# stopped                               0
# created_on                            0
# modified_on                           0
# Region                              105
# Departement                         122
# Commune                             112
# compteur_retard_rapport_agent_ec    166
# date_rapport_de_rappel              185
# rappels_de_rapport                  135
# reporting_month                     168
# date_rapport                        193
# mois_de_rapport                     179
# mois_dernier_rapport                179
# ec                                  138
# annee_en_cours                      193
# date_completude_du_rapport          221
# mois_de_rappel                      231
# dtype: int64

# %% [markdown]
# ### Filtrage du DataFrame par la région de Kolda

# %%
data_contacts_agents = data_contacts_agents.loc[data_contacts_agents['Region']=="REGION: Kolda"]

# %%
data_contacts_agents = data_contacts_agents.reset_index(drop=True)

# %% [markdown]
# ### Le type de données de chaque colonne du DataFrame

# %%
data_contacts_agents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
# name                                115 non-null object
# urns                                115 non-null object
# blocked                             115 non-null bool
# stopped                             115 non-null bool
# created_on                          115 non-null object
# modified_on                         115 non-null object
# Region                              115 non-null object
# Departement                         113 non-null object
# Commune                             115 non-null object
# compteur_retard_rapport_agent_ec    75 non-null object
# date_rapport_de_rappel              59 non-null object
# rappels_de_rapport                  115 non-null object
# reporting_month                     75 non-null object
# date_rapport                        52 non-null object
# mois_de_rapport                     62 non-null object
# mois_dernier_rapport                62 non-null object
# ec                                  112 non-null object
# annee_en_cours                      52 non-null object
# date_completude_du_rapport          29 non-null object
# mois_de_rappel                      19 non-null object
# dtypes: bool(2), object(18)
# memory usage: 16.5+ KB

# %%
##verification des agents dont dont date_rapport==0

# %% [markdown]
# ### Conversion du type des colonnes du Dataframe

# %%
data_contacts_agents=data_contacts_agents.astype({
    "name" : str,  "Region" : str,"Departement" : str, "Commune" : str, "reporting_month" : str,
    "mois_de_rapport" : str, "mois_dernier_rapport": str, "ec" :str, "mois_de_rappel" : str,
    "rappels_de_rapport" : int})
#urns

# %%
data_contacts_agents['annee_en_cours']
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 110    2019
# 111    None
# 112    None
# 113    None
# 114    None
# Name: annee_en_cours, Length: 115, dtype: object

# %%
data_contacts_agents['annee_en_cours'].fillna(0, inplace=True)

data_contacts_agents['annee_en_cours'] = data_contacts_agents['annee_en_cours'].astype(int)

# %%
import calendar
from datetime import date
import time

# %% [markdown]
# #### Conversion des colonnes définissant des dates au format datatime

# %%
data_contacts_agents.created_on = pd.to_datetime(data_contacts_agents.created_on) 
data_contacts_agents.modified_on = data_contacts_agents.modified_on 
data_contacts_agents.date_rapport_de_rappel=  pd.to_datetime(data_contacts_agents.date_rapport_de_rappel)
data_contacts_agents.date_rapport = pd.to_datetime(data_contacts_agents.date_rapport)

# %%
#time.localtime()
print(time.localtime().tm_year)
print(time.localtime().tm_mon)
# Out:
# 2020
# 4

# %% [markdown]
# ### Extraction du mois dans la variable 'date_rapport'

# %%
date_rapport_month = data_contacts_agents['date_rapport'].dt.month
date_rapport_de_rappel_month = data_contacts_agents['date_rapport_de_rappel'].dt.month
date_rapport_de_rappel_year = data_contacts_agents['date_rapport_de_rappel'].dt.year

# %% [markdown]
# ### Extraction du jour dans la variable 'date_rapport'

# %%
date_rapport_day = data_contacts_agents['date_rapport'].dt.day

# %% [markdown]
# ### Enumération des mois de l'année

# %%
mois_en_nombre= {'Janvier' : 1, 'Fevrier' : 2, 'Mars' : 3, 'Avril' : 4, 'Mai' : 5, 'Juin' : 6,
                 'Juillet' : 7, 'Aout': 8, 'Septembre' : 9, 'Octobre' : 10, 'Novembre' : 11,
                 'Decembre' : 12}

# %%
test= "Juillet" in mois_en_nombre

# %% [markdown]
# ### Définition de la fonction qui donne l'équivalent des mois en nombre

# %%
def Mois_en_nombre(col_mois):
    Mois_enumere= []
    for el in col_mois:
        if el in mois_en_nombre :
            k = mois_en_nombre.get(el)
        else :
            k = 0
        Mois_enumere.append(k)
    return Mois_enumere

# %% [markdown]
# ### Définition de la fonction qui donne le type de rapportage mensuel

# %%
def type_rapportage_mensuel(x,y):
    Type_rapportage = []
    for a in range(len(data_contacts_agents)):
        if (x[a] - y[a]) == 1 and  (date_rapport_day[a] <= 10):
            Type_rapportage.append('rapport')
        elif (x[a] - y[a]) == 1 and (date_rapport_day[a] >= 10)  and  (date_rapport_day[a] <= 31):
            Type_rapportage.append('retard')
        else :
            Type_rapportage.append('rappel')
    return Type_rapportage

# %% [markdown]
# ### Ajout de la colonne 'Type_rapportage_mensuel' au Dataframe

# %%
month_rapport =data_contacts_agents['mois_de_rapport']
#.astype(str)

# %%
Type_rapportage_mensuel = type_rapportage_mensuel(date_rapport_month,Mois_en_nombre(month_rapport))
data_contacts_agents['Type_rapportage_mensuel'] = Type_rapportage_mensuel
data_contacts_agents.head(5)
# Out:
#                    name                 urns  blocked  stopped  \
# 0         Thierno Balde  [tel:+221772274715]    False    False
# 1    Boubacar Niang Myf                   []    False    False
# 2         Amadou Diallo  [tel:+221772301137]    False    False
# 3            Maoudo Sow  [tel:+221771607528]    False    False
# 4  Mamadou Malado Sylla  [tel:+221770463545]    False    False
#
#                         created_on                  modified_on  \
# 0 2018-08-08 15:58:21.231678+00:00  2020-04-20T11:32:02.513763Z
# 1 2017-08-25 11:17:42.633780+00:00  2020-04-16T18:13:01.842715Z
# 2 2017-08-27 22:38:51.900502+00:00  2020-04-16T17:34:01.834487Z
# 3 2018-08-09 14:21:19.192594+00:00  2020-04-16T13:47:48.094575Z
# 4 2018-08-10 10:12:31.962892+00:00  2020-04-16T11:08:12.202380Z
#
#           Region Departement             Commune  \
# 0  REGION: Kolda       Kolda     Sare Yoba Diega
# 1  REGION: Kolda        None                 MYF
# 2  REGION: Kolda         MYF                Pata
# 3  REGION: Kolda   Vélingara  Sinthiang Koundara
# 4  REGION: Kolda         MYF          Dinguiraye
#
#   compteur_retard_rapport_agent_ec  ... rappels_de_rapport  reporting_month  \
# 0                                2  ...                  0          Juillet
# 1                                1  ...                  6          Juillet
# 2                                1  ...                  6          Juillet
# 3                                1  ...                  6          Juillet
# 4                                2  ...                  5          Juillet
#
#                       date_rapport mois_de_rapport mois_dernier_rapport    ec  \
# 0 2020-04-20 11:29:30.467883+00:00            Mars                 Mars   oui
# 1 2020-03-10 18:09:07.451954+00:00         Fevrier              Fevrier  None
# 2 2020-03-10 17:27:06.081372+00:00         Fevrier              Fevrier   oui
# 3 2020-03-05 17:23:18.071725+00:00         Fevrier                 Mars   oui
# 4 2020-04-16 11:03:54.106707+00:00            Mars                 Mars   oui
#
#   annee_en_cours  date_completude_du_rapport mois_de_rappel  \
# 0           2020                  20-04-2020           None
# 1           2020                  10-03-2020           None
# 2           2020                        None        Juillet
# 3           2020                        None           Mars
# 4           2020                  16-04-2020        Janvier
#
#   Type_rapportage_mensuel
# 0                  retard
# 1                 rapport
# 2                 rapport
# 3                 rapport
# 4                  retard
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Nombre de rapport mensuel par agent

# %%
def nombre_rapport(x,y):
    Nombre_rapport = []
    for a in range(len(data_contacts_agents)):
        if (x[a] - y[a]) == 1 :
            Nombre_rapport.append(1)
        else :
            Nombre_rapport.append(0)
    return Nombre_rapport

# %%
Nombre_rapport_mensuel = nombre_rapport(date_rapport_month,Mois_en_nombre(month_rapport))
data_contacts_agents['Nombre_rapport_mensuel'] = Nombre_rapport_mensuel
data_contacts_agents.head(5)
# Out:
#                    name                 urns  blocked  stopped  \
# 0         Thierno Balde  [tel:+221772274715]    False    False
# 1    Boubacar Niang Myf                   []    False    False
# 2         Amadou Diallo  [tel:+221772301137]    False    False
# 3            Maoudo Sow  [tel:+221771607528]    False    False
# 4  Mamadou Malado Sylla  [tel:+221770463545]    False    False
#
#                         created_on                  modified_on  \
# 0 2018-08-08 15:58:21.231678+00:00  2020-04-20T11:32:02.513763Z
# 1 2017-08-25 11:17:42.633780+00:00  2020-04-16T18:13:01.842715Z
# 2 2017-08-27 22:38:51.900502+00:00  2020-04-16T17:34:01.834487Z
# 3 2018-08-09 14:21:19.192594+00:00  2020-04-16T13:47:48.094575Z
# 4 2018-08-10 10:12:31.962892+00:00  2020-04-16T11:08:12.202380Z
#
#           Region Departement             Commune  \
# 0  REGION: Kolda       Kolda     Sare Yoba Diega
# 1  REGION: Kolda        None                 MYF
# 2  REGION: Kolda         MYF                Pata
# 3  REGION: Kolda   Vélingara  Sinthiang Koundara
# 4  REGION: Kolda         MYF          Dinguiraye
#
#   compteur_retard_rapport_agent_ec  ... reporting_month  \
# 0                                2  ...         Juillet
# 1                                1  ...         Juillet
# 2                                1  ...         Juillet
# 3                                1  ...         Juillet
# 4                                2  ...         Juillet
#
#                       date_rapport mois_de_rapport mois_dernier_rapport    ec  \
# 0 2020-04-20 11:29:30.467883+00:00            Mars                 Mars   oui
# 1 2020-03-10 18:09:07.451954+00:00         Fevrier              Fevrier  None
# 2 2020-03-10 17:27:06.081372+00:00         Fevrier              Fevrier   oui
# 3 2020-03-05 17:23:18.071725+00:00         Fevrier                 Mars   oui
# 4 2020-04-16 11:03:54.106707+00:00            Mars                 Mars   oui
#
#   annee_en_cours date_completude_du_rapport  mois_de_rappel  \
# 0           2020                 20-04-2020            None
# 1           2020                 10-03-2020            None
# 2           2020                       None         Juillet
# 3           2020                       None            Mars
# 4           2020                 16-04-2020         Janvier
#
#   Type_rapportage_mensuel Nombre_rapport_mensuel
# 0                  retard                      1
# 1                 rapport                      1
# 2                 rapport                      1
# 3                 rapport                      1
# 4                  retard                      1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Nombre de rapport de rappel mensuel par agent

# %%
def nombre_rapport_de_rappel(x,y):
    Nombre_rapport_de_rappel = []
    annee_en_cours= data_contacts_agents['annee_en_cours']
    for a in range(len(data_contacts_agents)):
        if (x[a] - y[a]) != 1 and  (date_rapport_de_rappel_year[a] == annee_en_cours[a]):
            Nombre_rapport_de_rappel.append(1)
        else :
            Nombre_rapport_de_rappel.append(0)
    return Nombre_rapport_de_rappel

# %%
Nombre_rapport_de_rappel_mensuel = nombre_rapport_de_rappel(date_rapport_de_rappel_month,Mois_en_nombre(month_rapport))
data_contacts_agents['Nombre_rapport_de_rappel_mensuel'] = Nombre_rapport_de_rappel_mensuel
data_contacts_agents.tail(5)
# Out:
#                        name                 urns  blocked  stopped  \
# 110       Souleymane Mballo  [tel:+221778296099]    False    False
# 111           Coumbel Balde  [tel:+221783891441]    False    False
# 112           Mamadou Balde  [tel:+221777432512]    False    False
# 113     Mamadou Samba Baldé  [tel:+221771048892]    False    False
# 114  Mamadou Lamarana Balde  [tel:+221775170511]    False    False
#
#                           created_on                  modified_on  \
# 110 2017-08-25 22:06:19.132847+00:00  2020-03-16T12:36:13.665919Z
# 111 2017-08-25 11:37:00.908293+00:00  2020-03-16T12:36:13.665919Z
# 112 2017-08-25 11:27:13.835658+00:00  2020-03-16T12:36:13.665919Z
# 113 2017-08-25 11:26:32.753602+00:00  2020-03-16T12:36:13.665919Z
# 114 2017-08-25 11:16:54.237901+00:00  2020-03-16T12:36:13.665919Z
#
#             Region Departement     Commune compteur_retard_rapport_agent_ec  \
# 110  REGION: Kolda       Kolda  Coumbacara                                1
# 111  REGION: Kolda         MYF  Fafacourou                                1
# 112  REGION: Kolda         MYF      Ndorna                             None
# 113  REGION: Kolda         MYF         MYF                             None
# 114  REGION: Kolda   Vélingara      Kandia                                1
#
#      ...                     date_rapport  mois_de_rapport  \
# 110  ... 2019-06-03 16:44:28.004445+00:00              Mai
# 111  ...                              NaT             None
# 112  ...                              NaT             None
# 113  ...                              NaT             None
# 114  ...                              NaT        Septembre
#
#     mois_dernier_rapport   ec annee_en_cours date_completude_du_rapport  \
# 110                  Mai  oui           2019                       None
# 111                 None  oui              0                       None
# 112                 None  oui              0                       None
# 113                 None  oui              0                       None
# 114            Septembre  oui              0                       None
#
#     mois_de_rappel  Type_rapportage_mensuel Nombre_rapport_mensuel  \
# 110        Janvier                  rapport                      1
# 111           None                   rappel                      0
# 112           None                   rappel                      0
# 113           None                   rappel                      0
# 114           None                   rappel                      0
#
#     Nombre_rapport_de_rappel_mensuel
# 110                                1
# 111                                0
# 112                                0
# 113                                0
# 114                                0
#
# [5 rows x 23 columns]

# %%
#data_contacts_agents[['date_rapport', 'mois_de_rapport','date_rapport_de_rappel','mois_de_rappel', 'Nombre_rapport_mensuel','Nombre_rapport_de_rappel_mensuel' ]]

# %% [markdown]
# ### Nombre de notifications d'envoi de rapport par mois par agent
# C'est équivalent à la valeur de la variable rappels_de_rapport.

# %% [markdown]
# ### Délai d'envoi de rapports à temps
# #### date_rapport - 1er jour succédant le mois_de_rapport

# %%
def delai_envoi_rapport(x,y):
    Delai_envoi_rapport = []
    for a in range(len(data_contacts_agents)):
        if data_contacts_agents['annee_en_cours'][a]== 0 :
            Delai_envoi_rapport.append('')
        else :
            first_delai = date(data_contacts_agents['annee_en_cours'][a], Mois_en_nombre(y)[a] + 1, 1)
            k = (x.dt.date[a] - first_delai).days 
            Delai_envoi_rapport.append(k)
    return Delai_envoi_rapport

# %%
Delai_envoi_rapport_mensuel = delai_envoi_rapport(data_contacts_agents['date_rapport'],data_contacts_agents['mois_de_rapport'])
data_contacts_agents['Delai_envoi_rapport_mensuel'] = Delai_envoi_rapport_mensuel
#data_contacts_agents['Delai_envoi_rapport_mensuel']= data_contacts_agents['Delai_envoi_rapport_mensuel'].replace(r'', np.NaN)
data_contacts_agents['Delai_envoi_rapport_mensuel'] = data_contacts_agents['Delai_envoi_rapport_mensuel'].astype(int, errors= 'ignore')
data_contacts_agents.head(5)
# Out:
#                    name                 urns  blocked  stopped  \
# 0         Thierno Balde  [tel:+221772274715]    False    False
# 1    Boubacar Niang Myf                   []    False    False
# 2         Amadou Diallo  [tel:+221772301137]    False    False
# 3            Maoudo Sow  [tel:+221771607528]    False    False
# 4  Mamadou Malado Sylla  [tel:+221770463545]    False    False
#
#                         created_on                  modified_on  \
# 0 2018-08-08 15:58:21.231678+00:00  2020-04-20T11:32:02.513763Z
# 1 2017-08-25 11:17:42.633780+00:00  2020-04-16T18:13:01.842715Z
# 2 2017-08-27 22:38:51.900502+00:00  2020-04-16T17:34:01.834487Z
# 3 2018-08-09 14:21:19.192594+00:00  2020-04-16T13:47:48.094575Z
# 4 2018-08-10 10:12:31.962892+00:00  2020-04-16T11:08:12.202380Z
#
#           Region Departement             Commune  \
# 0  REGION: Kolda       Kolda     Sare Yoba Diega
# 1  REGION: Kolda        None                 MYF
# 2  REGION: Kolda         MYF                Pata
# 3  REGION: Kolda   Vélingara  Sinthiang Koundara
# 4  REGION: Kolda         MYF          Dinguiraye
#
#   compteur_retard_rapport_agent_ec  ... mois_de_rapport  mois_dernier_rapport  \
# 0                                2  ...            Mars                  Mars
# 1                                1  ...         Fevrier               Fevrier
# 2                                1  ...         Fevrier               Fevrier
# 3                                1  ...         Fevrier                  Mars
# 4                                2  ...            Mars                  Mars
#
#      ec annee_en_cours date_completude_du_rapport mois_de_rappel  \
# 0   oui           2020                 20-04-2020           None
# 1  None           2020                 10-03-2020           None
# 2   oui           2020                       None        Juillet
# 3   oui           2020                       None           Mars
# 4   oui           2020                 16-04-2020        Janvier
#
#   Type_rapportage_mensuel  Nombre_rapport_mensuel  \
# 0                  retard                       1
# 1                 rapport                       1
# 2                 rapport                       1
# 3                 rapport                       1
# 4                  retard                       1
#
#   Nombre_rapport_de_rappel_mensuel Delai_envoi_rapport_mensuel
# 0                                0                          19
# 1                                0                           9
# 2                                0                           9
# 3                                0                           4
# 4                                0                          15
#
# [5 rows x 24 columns]

# %%
#data_contacts_agents[['date_rapport','date_completude_du_rapport']]

# %%
#date(2020,3,1)

# %% [markdown]
# ### Delai d'envoi de rapport de rappel
# #### date_rapport_de_rappel - 10eme jour succédant le mois_de_rappel

# %%
def delai_envoi_rapport_rappel(x,y):
    Delai_envoi_rapport_rappel = []
    for a in range(len(data_contacts_agents)):
        if data_contacts_agents['annee_en_cours'][a]== 0 or date_rapport_de_rappel_year[a] != data_contacts_agents['annee_en_cours'][a]:
            Delai_envoi_rapport_rappel.append('')
        else :
            first_delai = date(data_contacts_agents['annee_en_cours'][a], Mois_en_nombre(y)[a] + 1, 10)
            k = (x.dt.date[a] - first_delai).days 
            Delai_envoi_rapport_rappel.append(k)
    return Delai_envoi_rapport_rappel

# %%
Delai_envoi_rapport_rappel_mensuel = delai_envoi_rapport_rappel(data_contacts_agents['date_rapport_de_rappel'],data_contacts_agents['mois_de_rappel'])
data_contacts_agents['Delai_envoi_rapport_rappel_mensuel'] = Delai_envoi_rapport_rappel_mensuel
data_contacts_agents['Delai_envoi_rapport_rappel_mensuel'] = data_contacts_agents['Delai_envoi_rapport_rappel_mensuel'].astype(int, errors= 'ignore')
data_contacts_agents.head(5)
# Out:
#                    name                 urns  blocked  stopped  \
# 0         Thierno Balde  [tel:+221772274715]    False    False
# 1    Boubacar Niang Myf                   []    False    False
# 2         Amadou Diallo  [tel:+221772301137]    False    False
# 3            Maoudo Sow  [tel:+221771607528]    False    False
# 4  Mamadou Malado Sylla  [tel:+221770463545]    False    False
#
#                         created_on                  modified_on  \
# 0 2018-08-08 15:58:21.231678+00:00  2020-04-20T11:32:02.513763Z
# 1 2017-08-25 11:17:42.633780+00:00  2020-04-16T18:13:01.842715Z
# 2 2017-08-27 22:38:51.900502+00:00  2020-04-16T17:34:01.834487Z
# 3 2018-08-09 14:21:19.192594+00:00  2020-04-16T13:47:48.094575Z
# 4 2018-08-10 10:12:31.962892+00:00  2020-04-16T11:08:12.202380Z
#
#           Region Departement             Commune  \
# 0  REGION: Kolda       Kolda     Sare Yoba Diega
# 1  REGION: Kolda        None                 MYF
# 2  REGION: Kolda         MYF                Pata
# 3  REGION: Kolda   Vélingara  Sinthiang Koundara
# 4  REGION: Kolda         MYF          Dinguiraye
#
#   compteur_retard_rapport_agent_ec  ... mois_dernier_rapport    ec  \
# 0                                2  ...                 Mars   oui
# 1                                1  ...              Fevrier  None
# 2                                1  ...              Fevrier   oui
# 3                                1  ...                 Mars   oui
# 4                                2  ...                 Mars   oui
#
#   annee_en_cours date_completude_du_rapport mois_de_rappel  \
# 0           2020                 20-04-2020           None
# 1           2020                 10-03-2020           None
# 2           2020                       None        Juillet
# 3           2020                       None           Mars
# 4           2020                 16-04-2020        Janvier
#
#   Type_rapportage_mensuel Nombre_rapport_mensuel  \
# 0                  retard                      1
# 1                 rapport                      1
# 2                 rapport                      1
# 3                 rapport                      1
# 4                  retard                      1
#
#    Nombre_rapport_de_rappel_mensuel Delai_envoi_rapport_mensuel  \
# 0                                 0                          19
# 1                                 0                           9
# 2                                 0                           9
# 3                                 0                           4
# 4                                 0                          15
#
#   Delai_envoi_rapport_rappel_mensuel
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Temps moyen de rapportagede l'agent dans l'année
# moyenne(delai d'envoi de rapports) && annee_en_cours

# %%
from datetime import datetime
maintenant = datetime.now()
maintenant
# Out:
# datetime.datetime(2020, 4, 27, 11, 34, 8, 902211)

# %%
maintenant.month
# Out:
# 4

# %%
Delai_rapport = pd.DataFrame(columns=['Delai_rapport_Janvier','Delai_rapport_Fevrier','Delai_rapport_Mars','Delai_rapport_Avril','Delai_rapport_Mai','Delai_rapport_Juin','Delai_rapport_Juillet','Delai_rapport_Aout','Delai_rapport_Septembre','Delai_rapport_Octobre','Delai_rapport_Novembre','Delai_rapport_Decembre'], dtype='int')

# %%
if maintenant.month == 2 :
     Delai_rapport['Delai_rapport_Janvier'] = Delai_envoi_rapport_mensuel  
if maintenant.month == 3 :
     Delai_rapport['Delai_rapport_Fevrier'] = Delai_envoi_rapport_mensuel
if maintenant.month == 4 :
     Delai_rapport['Delai_rapport_Mars'] = Delai_envoi_rapport_mensuel
if maintenant.month == 5 :
     Delai_rapport['Delai_rapport_Avril'] = Delai_envoi_rapport_mensuel
if maintenant.month == 6 :
     Delai_rapport['Delai_rapport_Mai'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 7 :
     Delai_rapport['Delai_rapport_Juin'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 8 :
     Delai_rapport['Delai_rapport_Juillet'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 9 :
     Delai_rapport['Delai_rapport_Aout'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 10 :
     Delai_rapport['Delai_rapport_Septembre'] = Delai_envoi_rapport_mensuel
if maintenant.month == 11 :
     Delai_rapport['Delai_rapport_Octobre'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 12 :
     Delai_rapport['Delai_rapport_Novembre'] = Delai_envoi_rapport_mensuel
if  maintenant.month == 1 :
     Delai_rapport['Delai_rapport_Decembre'] = Delai_envoi_rapport_mensuel

# %%
Delai_rapport=Delai_rapport.replace(r'', np.NaN)

# %%
def time_to_date(tab_delai, k):
    Temps_moyen_rapportage=[]
    for a in range(len(tab_delai)):
        i=2
        somme_delai=0
        while i <= (k-2):
                somme_delai = somme_delai +tab_delai.iloc[a,i] 
                i= i+1
        Temps_moyen_rapportage.append(somme_delai / (k - 3)) 
    return Temps_moyen_rapportage

# %%
Temps_moyen_rapportage = time_to_date(Delai_rapport,maintenant.month)
data_contacts_agents['Temps_moyen_rapportage']= Temps_moyen_rapportage
data_contacts_agents.head(5)

# %% [markdown]
# ### Temps moyen d'envoi de rapport de rappels  dans l'annee
# moyenne(delai d'envoi de rapport de rappel) && annee_en_cours

# %%
Delai_rapport_rappel = pd.DataFrame(columns=['Delai_rapport_rappel_Janvier','Delai_rapport_rappel_Fevrier','Delai_rapport_rappel_Mars','Delai_rapport_rappel_Avril','Delai_rapport_rappel_Mai','Delai_rapport_rappel_Juin','Delai_rapport_rappel_Juillet','Delai_rapport_rappel_Aout','Delai_rapport_rappel_Septembre','Delai_rapport_rappel_Octobre','Delai_rapport_rappel_Novembre','Delai_rapport_rappel_Decembre'], dtype='int')

# %%
if maintenant.month == 2 :
     Delai_rapport_rappel['Delai_rapport_rappel_Janvier'] = Delai_envoi_rapport_rappel_mensuel  
if maintenant.month == 3 :
     Delai_rapport_rappel['Delai_rapport_rappel_Fevrier'] = Delai_envoi_rapport_rappel_mensuel
if maintenant.month == 4 :
     Delai_rapport_rappel['Delai_rapport_rappel_Mars'] = Delai_envoi_rapport_rappel_mensuel
if maintenant.month == 5 :
     Delai_rapport_rappel['Delai_rapport_rappel_Avril'] = Delai_envoi_rapport_rappel_mensuel
if maintenant.month == 6 :
     Delai_rapport_rappel['Delai_rapport_rappel_Mai'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 7 :
     Delai_rapport_rappel['Delai_rapport_rappel_Juin'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 8 :
     Delai_rapport_rappel['Delai_rapport_rappel_Juillet'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 9 :
     Delai_rapport_rappel['Delai_rapport_rappel_Aout'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 10 :
     Delai_rapport_rappel['Delai_rapport_rappel_Septembre'] = Delai_envoi_rapport_rappel_mensuel
if maintenant.month == 11 :
     Delai_rapport_rappel['Delai_rapport_rappel_Octobre'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 12 :
     Delai_rapport_rappel['Delai_rapport_rappel_Novembre'] = Delai_envoi_rapport_rappel_mensuel
if  maintenant.month == 1 :
     Delai_rapport_rappel['Delai_rapport_rappel_Decembre'] = Delai_envoi_rapport_rappel_mensuel

# %%
Delai_rapport_rappel=Delai_rapport_rappel.replace(r'', np.NaN)

# %%
Temps_moyen_rapportage_rappel = time_to_date(Delai_rapport_rappel,maintenant.month)
data_contacts_agents['Temps_moyen_rapportage_rappel']= Temps_moyen_rapportage_rappel
data_contacts_agents.head(5)

# %% [markdown]
# ### Nombre des agents ayant délivrés 12 rapports
# somme des rapports + somme des rapports de rappel

# %%
Nombre_rapport =pd.DataFrame(columns=['Nombre_rapport_Janvier', 'Nombre_rapport_Fevrier', 'Nombre_rapport_Mars', 'Nombre_rapport_Avril', 'Nombre_rapport_Mai', 'Nombre_rapport_Juin', 'Nombre_rapport_Juillet','Nombre_rapport_Aout','Nombre_rapport_Septembre', 'Nombre_rapport_Octobre', 'Nombre_rapport_Novembre', 'Nombre_rapport_Decembre'], dtype='int')

# %%
somme_rapport_mensuel= data_contacts_agents['Nombre_rapport_mensuel'] + data_contacts_agents['Nombre_rapport_de_rappel_mensuel']
if maintenant.month == 2 :
     Nombre_rapport['Nombre_rapport_Janvier'] = somme_rapport_mensuel
if maintenant.month == 3 :
     Nombre_rapport['Nombre_rapport_Fevrier'] = somme_rapport_mensuel
if maintenant.month == 4 :
     Nombre_rapport['Nombre_rapport_Mars'] = somme_rapport_mensuel
if maintenant.month == 5 :
     Nombre_rapport['Nombre_rapport_Avril'] = somme_rapport_mensuel
if maintenant.month == 6 :
       Nombre_rapport['Nombre_rapport_Mai'] = somme_rapport_mensuel
if  maintenant.month == 7 :
      Nombre_rapport['Nombre_rapport_Juin'] = somme_rapport_mensuel
if  maintenant.month == 8 :
      Nombre_rapport['Nombre_rapport_Juillet'] = somme_rapport_mensuel
if  maintenant.month == 9 :
      Nombre_rapport['Nombre_rapport_Aout'] = somme_rapport_mensuel
if  maintenant.month == 10 :
      Nombre_rapport['Nombre_rapport_Septembre'] = somme_rapport_mensuel
if maintenant.month == 11 :
     Nombre_rapport['Nombre_rapport_Octobre'] = somme_rapport_mensuel
if  maintenant.month == 12 :
      Nombre_rapport['Nombre_rapport_Novembre'] = somme_rapport_mensuel
if  maintenant.month == 1 :
      Nombre_rapport['Nombre_rapport_Decembre'] = somme_rapport_mensuel

# %%
def nombre_rapports_delivres(tab_delai, k):
    Nombre_rapports_delivres=[]
    for a in range(len(tab_delai)):
        i=2
        total_rapport=0
        while i <= (k-2):
                #Delai_rapport.iloc[:,2].replace(r'', np.NaN)
                total_rapport = total_rapport +tab_delai.iloc[a,i] 
                i= i+1
        Nombre_rapports_delivres.append(total_rapport) 
    return Nombre_rapports_delivres

# %%
Nombre_rapports_delivres= nombre_rapports_delivres(Nombre_rapport, maintenant.month)

# %%
data_contacts_agents['Nombre_rapports_delivres']= Nombre_rapports_delivres
data_contacts_agents.head(5)
# Out:
#                    name                 urns  blocked  stopped  \
# 0         Thierno Balde  [tel:+221772274715]    False    False
# 1    Boubacar Niang Myf                   []    False    False
# 2         Amadou Diallo  [tel:+221772301137]    False    False
# 3            Maoudo Sow  [tel:+221771607528]    False    False
# 4  Mamadou Malado Sylla  [tel:+221770463545]    False    False
#
#                         created_on                  modified_on  \
# 0 2018-08-08 15:58:21.231678+00:00  2020-04-20T11:32:02.513763Z
# 1 2017-08-25 11:17:42.633780+00:00  2020-04-16T18:13:01.842715Z
# 2 2017-08-27 22:38:51.900502+00:00  2020-04-16T17:34:01.834487Z
# 3 2018-08-09 14:21:19.192594+00:00  2020-04-16T13:47:48.094575Z
# 4 2018-08-10 10:12:31.962892+00:00  2020-04-16T11:08:12.202380Z
#
#           Region Departement             Commune  \
# 0  REGION: Kolda       Kolda     Sare Yoba Diega
# 1  REGION: Kolda        None                 MYF
# 2  REGION: Kolda         MYF                Pata
# 3  REGION: Kolda   Vélingara  Sinthiang Koundara
# 4  REGION: Kolda         MYF          Dinguiraye
#
#   compteur_retard_rapport_agent_ec  ... date_completude_du_rapport  \
# 0                                2  ...                 20-04-2020
# 1                                1  ...                 10-03-2020
# 2                                1  ...                       None
# 3                                1  ...                       None
# 4                                2  ...                 16-04-2020
#
#    mois_de_rappel Type_rapportage_mensuel Nombre_rapport_mensuel  \
# 0            None                  retard                      1
# 1            None                 rapport                      1
# 2         Juillet                 rapport                      1
# 3            Mars                 rapport                      1
# 4         Janvier                  retard                      1
#
#   Nombre_rapport_de_rappel_mensuel Delai_envoi_rapport_mensuel  \
# 0                                0                          19
# 1                                0                           9
# 2                                0                           9
# 3                                0                           4
# 4                                0                          15
#
#   Delai_envoi_rapport_rappel_mensuel  Temps_moyen_rapportage  \
# 0                                                       19.0
# 1                                                        9.0
# 2                                                        9.0
# 3                                                        4.0
# 4                                                       15.0
#
#   Temps_moyen_rapportage_rappel Nombre_rapports_delivres
# 0                           NaN                        1
# 1                           NaN                        1
# 2                           NaN                        1
# 3                           NaN                        1
# 4                           NaN                        1
#
# [5 rows x 28 columns]
